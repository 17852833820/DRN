# %%
"""
 qp2=qp2*0.8
I frame qp= 50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[40:70]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[30:60]
"""
import numpy as np
B=0.0001
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:90.21588526106439
# Average size:61.11999002243322

# %%
"""
 qp2=qp2*0.75
I frame qp= 45
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=0.0002
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:86.02699341877474
# Average size:54.74569106062187

# %%
"""
 qp2=qp2*0.62
I frame qp= 34
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[25:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.0004
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:72.20852856644008
# Average size:47.747027924144405

# %%
"""
 qp2=qp2*0.7
I frame qp= 40
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[25:55]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[20:50]
"""
import numpy as np
B=0.0003
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:77.56334362125556
# Average size:50.25257427744157

# %%
"""
 qp2=qp2*0.6
I frame qp=29
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[20:60]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[15:45]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[10:40]

"""
import numpy as np
B=0.0005
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:62.103151837255005
# Average size:44.68912053944074

# %%
"""
 qp2=qp2*0.999
I frame qp=85
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[70:100]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[70:100]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[70:100]
"""
import numpy as np
B=0.000005
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# time: 0, acc:96.25726026647231, size : 326.40251608455884
# time: 1, acc:96.53338264016544, size : 311.88068704044116
# time: 2, acc:94.81539445764878, size : 315.2288028492647
# time: 3, acc:94.10466306349811, size : 314.25304457720586
# time: 4, acc:95.17731105580049, size : 318.7373046875
# time: 5, acc:96.48382242988137, size : 325.44347426470586
# time: 6, acc:96.56775979434742, size : 322.6490693933824
# time: 7, acc:96.31513707778034, size : 322.31497012867646
# time: 8, acc:95.90360697577981, size : 327.27814797794116
# time: 9, acc:94.426228018368, size : 338.33869485294116
# time: 10, acc:94.49512537787942, size : 340.17658547794116
# time: 11, acc:95.64359328326057, size : 333.6304572610294
# time: 12, acc:95.72584208320168, size : 341.53125
# time: 13, acc:96.79087751051959, size : 353.9046989889706
# time: 14, acc:96.46747252520393, size : 338.7090418198529
# time: 15, acc:94.64898109436035, size : 346.9755859375
# time: 16, acc:95.97154785605038, size : 339.0696231617647
# time: 17, acc:95.73443917667164, size : 365.22047334558823
# time: 18, acc:94.9398489559398, size : 361.6024816176471
# time: 19, acc:95.10088808396283, size : 358.3876953125
# time: 20, acc:94.16264646193561, size : 343.5371668198529
# time: 21, acc:95.39425513323616, size : 331.4837431066176
# time: 22, acc:94.85104224261116, size : 335.94944852941177
# time: 23, acc:94.57906274234547, size : 349.94772518382354
# time: 24, acc:93.36894820718204, size : 372.2611443014706
# time: 25, acc:92.54837316625259, size : 376.4976447610294
# time: 26, acc:90.49694678362678, size : 347.59886259191177
# time: 27, acc:91.3153423982508, size : 331.22351792279414
# time: 28, acc:93.90795371111702, size : 329.8555261948529
# time: 29, acc:95.4974230598001, size : 331.07249540441177
# time: 30, acc:96.972936742446, size : 370.98391544117646
# time: 31, acc:96.71807008631089, size : 353.51516544117646
# time: 32, acc:96.47517484777114, size : 362.42687270220586
# time: 33, acc:96.80517140556785, size : 373.6943933823529
# time: 34, acc:96.37511197258445, size : 375.60816865808823
# Average Acc:95.19490694163837
# Average size:343.2624931526502

# %%
"""
 qp2=qp2*0.95
I frame qp=75
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[65:95]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[60:90]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[55:85]
"""
import numpy as np
B=0.00001
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:95.052960798617
# Average size:157.85003162823455

# %%
"""
 qp2=qp2*0.9
I frame qp=55
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[45:75]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[40:70]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[35:65]
"""
import numpy as np
B=0.00005
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:93.29585201155164
# Average size:70.92644153015442

# %%
"""
 qp2=qp2*0.82
I frame qp=50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[40:70]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[30:60]
"""
import numpy as np
B=0.00008
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:91.01873455143134
# Average size:62.85591382773372

# %%
"""
 qp2=qp2*0.92
I frame qp=65
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[55:85]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[50:80]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[45:75]
"""
import numpy as np
B=0.00003
fps=8.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:94.59791684986554
# Average size:91.32453014138147
