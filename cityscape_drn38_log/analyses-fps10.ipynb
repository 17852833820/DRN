# %%
"""
 qp2=qp2*0.999
I frame qp=85
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[70:100]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[70:100]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[70:100]
"""
import numpy as np
B=0.000005
fps=10.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:96.25845591227214
# Average size:397.92102864583336

# %%
"""
 qp2=qp2*0.95
I frame qp=75
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[65:95]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[60:90]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[55:85]
"""
import numpy as np
B=0.00001
fps=10.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:95.35319132478487
# Average size:210.69223934421953

# %%
"""
 qp2=qp2*0.9
I frame qp=55
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[45:75]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[40:70]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[35:65]
"""
import numpy as np
B=0.00005
fps=10.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:93.68085717916091
# Average size:93.9858292466611

# %%
"""
 qp2=qp2*0.82
I frame qp=50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[40:70]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[30:60]
"""
import numpy as np
B=0.00008
fps=10.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:91.60216001915016
# Average size:82.31809037197412

# %%
"""
 qp2=qp2*0.5
I frame qp=15
    self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[0:30]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[0:30]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[0:30]
"""
import numpy as np
B=0.001
fps=10.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:56.189616335453294
# Average size:45.19157091245826

# %%
# """
#  qp2=qp2*0.55
# I frame qp=25
#     self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[10:40]
#             self.tables1U = torch.load('./pth/jpeg_qtables.pth')[5:35]
#             self.tables1V = torch.load('./pth/jpeg_qtables.pth')[0:30]
# """
# import numpy as np
# B=0.0005
# fps=10.0
# filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
# file = open(filename, 'r')
# line=0
# loss_data=[]
# second_data=[]
# V_data=[]
# for eachline in file:
#   if eachline.find("Loss") >= 0 and line>0:
#       loss_data.append(eachline)
#   if eachline.find("compressed size") >= 0 and line>0:
#       V_data.append(eachline)
#   if eachline.find("Average Acc") >=0 :
#     second_data.append(eachline)
#   line+=1
# file.close()
# # every second average
# second_acc=[]
# second_size=[]
# for info in second_data:
#     info=info.split(" ")
#     second_acc.append(info[2])
#     second_acc.append(info[5])
#     # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
# loss=[]
# acc=[]
# V=[]
# index=0
# # 599 average
# for info in loss_data:
#     info=info.split(" ")[4].split(",")
#     acc.append(float(info[1].split(":")[1]))
#     index+=1
# average_acc=np.mean(np.abs(np.array(acc)))
# print("Average Acc:{0}".format(average_acc))
# index=0
# for info in V_data:
#     info=info.split(",")
#     V.append(float(info[-2].split(":")[1]))
#     index+=1
# average_V=np.mean(np.abs(np.array(V)))
# print("Average size:{0}".format(average_V))
# Out:
# Average Acc:56.805843662140965
# Average size:51.58445879851836

# %%
"""
 qp2=qp2*0.6
I frame qp=29
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[20:60]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[15:45]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[10:40]

"""
import numpy as np
B=0.000501
fps=10.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:67.02368430581834
# Average size:59.27226692925709

# %%
"""
 qp2=qp2*0.65
I frame qp= 34
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[25:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.0004
fps=10.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:76.35724134556638
# Average size:63.696902063334726

# %%
"""
 qp2=qp2*0.7
I frame qp= 45
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=0.0002
fps=10.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:85.78179587107867
# Average size:70.242386399207
