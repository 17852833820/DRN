# %%
"""
 qp2=qp2*0.88
I frame qp=65
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[55:85]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[50:80]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[45:75]
"""
import numpy as np
B=0.00003
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:93.3339497879869
# Average size:50.78706372600167

# %%
"""
 qp2=qp2*0.8
I frame qp=50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[40:70]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[30:60]
"""
import numpy as np
B=0.00008
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:90.18418259533101
# Average size:36.060843593489146

# %%
"""
 qp2=qp2*0.85
I frame qp=55
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[45:75]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[40:70]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[35:65]
"""
import numpy as np
B=0.00005
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:92.39659436756064
# Average size:40.33112316099749

# %%
"""
 qp2=qp2*0.92
I frame qp=75
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[65:95]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[60:90]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[55:85]
"""
import numpy as np
B=0.00001
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:94.14487243295711
# Average size:73.59955231375208

# %%
"""
 qp2=qp2*0.999
I frame qp=85
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[70:100]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[70:100]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[70:100]
"""
import numpy as np
B=0.000005
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:94.62560532686109
# Average size:200.74059304570116

# %%
"""
 qp2=qp2*0.6
I frame qp=29
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[20:60]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[15:45]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[10:40]

"""
import numpy as np
B=0.0005
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=00
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:59.80527150213022
# Average size:26.00214061195743

# %%
"""
 qp2=qp2*0.7
I frame qp= 40
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[25:55]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[20:50]
"""
import numpy as np
B=0.0003
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=00
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:75.97000618808855
# Average size:29.16023287510434

# %%
"""
 qp2=qp2*0.62
I frame qp= 34
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[25:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.0004
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:69.31999020266015
# Average size:27.83844819490818

# %%
"""
 qp2=qp2*0.75
I frame qp= 45
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=0.0002
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:85.77760479884076
# Average size:31.839450842550082

# %%
"""
 qp2=qp2*0.8
I frame qp= 50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[40:70]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[30:60]
"""
import numpy as np
B=0.0001
fps=5.0
filename="fps={0}/test-B={1}-fps={2}.log".format(int(fps),B,(fps))
file = open(filename, 'r')
line=0
loss_data=[]
second_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0 and line>0:
      V_data.append(eachline)
  if eachline.find("Average Acc") >=0 :
    second_data.append(eachline)
  line+=1
file.close()
# every second average
second_acc=[]
second_size=[]
for info in second_data:
    info=info.split(" ")
    second_acc.append(info[2])
    second_acc.append(info[5])
    # print("time: {0}, acc:{1}, size : {2}".format(info[27].strip('\n'),info[8],info[16]))
loss=[]
acc=[]
V=[]
index=0
# 599 average
for info in loss_data:
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
print("Average Acc:{0}".format(average_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))
# Out:
# Average Acc:89.98019110181296
# Average size:35.610565134599334
