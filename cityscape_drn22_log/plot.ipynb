# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"""fps difference"""
V=[
    #58,
    62.59,#0.004
#71.52,#0.001
#75.11,#0.0005
#79.32,#0.0003
#78.57,#B=0.0002
86.54,# #B=0.0001003
92.22,#B=0.0001
95.17,#B=9e-05
96.95,#B=8e-05
109.83,#B=7e-05
119.78,#B=6.002e-05
146.60,#4e-05
165.91,
194.24,
218.18, 
372.92]
Accuracy=[
    #59,
    54.92,#0.004
#55.19,#B=0.001
#48.26,#B=0.0005
#60.00,#B=0.0003
#57.91,#B=0.0002
71.20, #B=0.0001003
76.80,#B=0.0001
79.28,#B=9e-05
81.20,#B=8e-05
87.42,#B=7e-05 
90.18,#B=6.002e-05
94.59,#4e-05
95.66,
96.57,
97.05,
98.83]
jpeg_real_V=[
    # 0,
   # 0,
    0,
    0,
    0,
    # 59.08,
    72.58,
    88.69,
    104.43,
    118.85,#39
    134.05,#49
    151.18,
    179.19,
    228.23,
    360.40,
    #1490.18
]
jpeg_real_acc=[
    # 0,
    0,
    0,
    #0,
    0,
    # 40.21,
    34.32,
    43.35,
    56.34,
    69.47,
    79.92,
    86.92,
    93.59,
    97.18,
    98.61,
    #99.63
]

V_fps3=[
    18.15,#0.0003
    20.16,#0.0001
    24.79,#8.001e-05
    25.98,#6e-05
    26.98,#5e-05
    29.06,#5.001e-05
    32.37,#4e-05
    35.95,#4.002e-05
    49.27,#0.00001
]
Acc_fps3=[
    53.63,
    63.29,
   77.83,
   81.83,
   83.50,
   86.89,
   89.29,
   91.22,
   93.79]
our_V_h264=[60.56,66.52,72.99,86.57,95.24,110,137.65,219.38,369.85,1113.72]
our_Acc_h264=[10.82,21.25,43.14,71.25,79.26,87.61,93.81,97.12,98.35,99.16]
our_V_h264_2s=[70.39,83.73,92.31,107.02,134.72,218.09,369.37,1114.44]
our_Acc_h264_2s=[42.56,71.52,79.59,87.92,94.15,97.52,98.59,99.22]
"""fps=17"""
V_new=[
    86.2,
   93.58,
    97.15,
    #111.29,
    100.91,
    108.29,
    #111.76,
    #111.0,
    #132.65,
 
    112.42,
    #118.55,
    #118.92,
    #120.72,
    124.03,
    #128.00,
    #111.33,
    127.36,
    146.97,
    221.16,
    ]
Acc_new=[
    73.87,#2.002e-04
    81.69, #2.001e-04
    83.69,#0.7  6e-05
    #90.61,#0.8 6e-05
    86.11,#8e-05
    89.9,# 6.007E-05
    #90.87,#0.8 6.006e-05 
    #90.49, # 0.8 7e-05
    #92.78,
    
    92.82, #0.83  6.005e-05
    #92.53,
    #92.59, #0.832 6.0010e-05
    #93.07,#0.84 6.0009e-05
    93.44,# 0.85 6.0008e-05
    #93.14,  #0.87 7e-05
    #90.54,#5e-05
    93.91,  # 0.85 5.004e=05
    95.41,#4,001e-05
    97.28,#1.001e-05
    ]

"""fps="""
label_size=15*14/17
V_fps3_new=[
13.28,
18.08,#15*14/17,
20.36,
24.54,
25.55,

#27.21
32.28,
#28.48
32.39,
35.64,
#52.45,
49.15,#+15*14/17,
79.89,#+15*14/17,
107.5,#+15*14/17,
145.97#+15*14/17
]

Acc_fps3_new=[
    39.92,#B=0.001
46.82,#B=0.000301
55.29,#B=0.000101
73.76,#B=8.002e-05
78.33,#B=0.0000601

# 79.88,
87.31,#B=0.00004003
# 84,
88.81,#B=0.0000301
90.51,#B=0.00004004
#94.04,
94.21,#B=0.0000101
95.37,#B=1.001e-06
95.77,#B=1.001e-07
96#B=1.002e-07
]
Acc_fps3_new_version2=[37.49 ,   47.18,   55.65,  73.06,  77.18,84.48,   84.85,   86.75,    88.86,     89.35,   89.54,  89.60 ]

V_fps10_new=[36.56,44.18,60.21,67.59,69.96,77.28,88.83,107.10,145.69,382.42]
Acc_fps10_new=[38.69,42.58,68.36,78.58,80.80,86.2,91.03,93.88,95.76,98.07] 
Acc_fps10_new_version=[  35.94, 40.70, 67.86,78.08, 80.22,   85.46, 90.16,93.14,94.31,95.86]

V_fps8_new=[25.94,   32.38, 46.35,54.01  ,  59.88,  69.10,81.44,99.26,    283.73]
Acc_fps8_new=[38.56, 42.09,  66.46,78.77,  84.73,90.06,93.05,94.65,    97.51]
Acc_fps8_new_version2=[ 35.26,39.70,65.74, 78.04,83.80,88.83,  91.57, 92.98,94.93]

V_fps5_new=[14.25,18.11,27.79, 33.43,33.68,34.09,36.18,  42.43, 45.30,59.33, 62.25,87.39,96.02,108.49,166.24,288.64]
Acc_fps5_new=[36.75,40.26,65.68,78.17,78.96,  82.71,83.38, 90.19, 91.34,  93.94,94.25,95.63,95.74,96.02,96.54,96.66]
Acc_fps5_new_version2=[ 32.75, 38.28,64.46,76.84,77.24,81.25,81.84,88.21,89.20,91.37,91.60,92.64,92.71, 92.86,93.14,93.19]

colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            

plt.plot(our_V_h264,our_Acc_h264,c="blue",alpha=0.5)
plt.plot(V_new,Acc_new,c="red",marker="o",alpha=0.5)
# plt.plot(V_fps10_new,Acc_fps10_new,c="orange",marker="o",alpha=0.5)
plt.plot(V_fps10_new,Acc_fps10_new_version,c="orange",alpha=0.5)
# plt.plot(V_fps8_new,Acc_fps8_new,c="black",marker="o",alpha=0.5)
plt.plot(V_fps8_new,Acc_fps8_new_version2,c="black",alpha=0.5)
# plt.plot(V_fps5_new,Acc_fps5_new,c="red",marker="o",alpha=0.5)
plt.plot(V_fps5_new,Acc_fps5_new_version2,c="red",alpha=0.5)
# plt.plot(V_fps3_new,Acc_fps3_new,c="green",marker="o",alpha=0.5)
plt.plot(V_fps3_new,Acc_fps3_new_version2,c="green",alpha=0.5)
#plt.plot(V_fps3,Acc_fps3,c="green",alpha=0.4)
plt.legend(["H264","fps=17","fps=10","","fps=8","","fps=5","","fps=3"],loc=4,fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
# plt.ylim(90,100)
plt.xlim(0,800)                                                                                                                                                                                                      
plt.savefig("results5.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"""cityscape drn 22"""
"""add  return time acc update"""
our_V_h264=[60.56,66.52,72.99,86.57,95.24,110,137.65,219.38,369.85,1113.72]
our_Acc_h264=[10.82,21.25,43.14,71.25,79.26,87.61,93.81,97.12,98.35,99.16]
V_new=[
    86.2,
   93.58,
    97.15,
    #111.29,
    100.91,
    108.29,
    #111.76,
    #111.0,
    #132.65,
 
    112.42,
    #118.55,
    #118.92,
    #120.72,
    124.03,
    #128.00,
    #111.33,
    127.36,
    146.97,
    221.16,
    ]
Acc_new=[
    73.87,#2.002e-04
    81.69, #2.001e-04
    83.69,#0.7  6e-05
    #90.61,#0.8 6e-05
    86.11,#8e-05
    89.9,# 6.007E-05
    #90.87,#0.8 6.006e-05 
    #90.49, # 0.8 7e-05
    #92.78,
    
    92.82, #0.83  6.005e-05
    #92.53,
    #92.59, #0.832 6.0010e-05
    #93.07,#0.84 6.0009e-05
    93.44,# 0.85 6.0008e-05
    #93.14,  #0.87 7e-05
    #90.54,#5e-05
    93.91,  # 0.85 5.004e=05
    95.41,#4,001e-05
    97.28,#1.001e-05
    ]

"""fps="""
label_size=15*14/17
V_fps3_new=[13.28,18.08,20.36,24.54,25.55,32.28,32.39,35.64,49.15,79.89,107.5,145.97]
Acc_fps3_new_version2=[37.49 ,   47.18,   55.65,  73.06,  77.18,84.48,   84.85,   86.75,    88.86,     89.35,   89.54,  89.60 ]
V_fps10_new=[36.56,44.18,60.21,67.59,69.96,77.28,88.83,107.10,145.69,382.42]
Acc_fps10_new_version=[  35.94, 40.70, 67.86,78.08, 80.22,   85.46, 90.16,93.14,94.31,95.86]
V_fps8_new=[25.94,   32.38, 46.35,54.01  ,  59.88,  69.10,81.44,99.26,    283.73]
Acc_fps8_new_version2=[ 35.26,39.70,65.74, 78.04,83.80,88.83,  91.57, 92.98,94.93]
V_fps5_new=[14.25,18.11,27.79, 33.43,33.68,34.09,36.18,  42.43, 45.30,59.33, 62.25,87.39,96.02,108.49,166.24,288.64]
Acc_fps5_new_version2=[ 32.75, 38.28,64.46,76.84,77.24,81.25,81.84,88.21,89.20,91.37,91.60,92.64,92.71, 92.86,93.14,93.19]
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            

plt.plot(our_V_h264,our_Acc_h264,c="blue",alpha=0.5)
plt.plot(V_new,Acc_new,c="red",alpha=0.5)
# plt.plot(V_fps10_new,Acc_fps10_new,c="orange",alpha=0.5)
plt.plot(V_fps10_new,Acc_fps10_new_version,c="orange",alpha=0.5)
# plt.plot(V_fps8_new,Acc_fps8_new,c="black",alpha=0.5)
plt.plot(V_fps8_new,Acc_fps8_new_version2,c="black",alpha=0.5)
# plt.plot(V_fps5_new,Acc_fps5_new,c="red",alpha=0.5)
plt.plot(V_fps5_new,Acc_fps5_new_version2,c="red",alpha=0.5)
# plt.plot(V_fps3_new,Acc_fps3_new,c="green",alpha=0.5)
plt.plot(V_fps3_new,Acc_fps3_new_version2,c="green",alpha=0.5)
#plt.plot(V_fps3,Acc_fps3,c="green",alpha=0.4)
plt.legend(["H264","fps=17","fps=10","","fps=8","","fps=5","","fps=3"],loc=4,fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(60,100)
plt.xlim(0,400)                                                                                                                                                                                                      
plt.savefig("results5.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"""cityscape drn 22"""
"""add  return time acc update"""
our_V_h264=[60.56,66.52,72.99,86.57,95.24,110,137.65,219.38,369.85,1113.72]
our_Acc_h264=[10.82,21.25,43.14,71.25,79.26,87.61,93.81,97.12,98.35,99.16]
"""fps="""
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
V_best_drn22_cityscape=[13.28,18.08,20.36,24.54,25.55,32.28,32.39,35.64,
42.43, 45.30,59.33, 62.25,87.39,
99.26,
107.10,
127.36,146.97,#221.16,
218.09,369.37,1114.44
]
Acc_best_drn22_cityscape=[37.49 ,   47.18,   55.65,  73.06,  77.18,84.48,   84.85,   86.75, 
88.21,89.20,91.37,91.60,92.64,  #5fps
92.98,
93.14,
93.91,  95.41, #97.28,  17fps
97.52,98.59,99.22
]
V_best_drn22_cityscape_raw=[13.28,18.08,20.36,24.54,25.55,32.39,35.64,49.15,79.89,
87.39,96.02,108.49,166.24,
221.16,
283.73,
382.42,

]

ACC_best_drn22_cityscape_raw=[ 39.92,46.82,55.29,73.76,78.33,88.81,90.51,94.21,95.37,
95.63,95.74,96.02,96.54,
97.28,
97.51,
98.07,
]
# plt.plot(our_V_h264,our_Acc_h264,c="blue",marker="*",alpha=0.5)
plt.plot(V_new,Acc_new,c="blue",marker="*",alpha=0.5)
plt.plot(V_fps10_new,Acc_fps10_new_version,c="red",marker="*",alpha=0.5)
plt.plot(V_fps8_new,Acc_fps8_new_version2,c="green",marker="*",alpha=0.5)
plt.plot(V_fps5_new,Acc_fps5_new_version2,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps3_new,Acc_fps3_new_version2,c="blue",marker="*",alpha=0.3)
plt.plot(V_best_drn22_cityscape,Acc_best_drn22_cityscape,c="black",marker="o",alpha=0.5)
# plt.plot(V_best_drn22_cityscape_raw,ACC_best_drn22_cityscape_raw,c="green",marker="o",alpha=0.5)

plt.legend(["fps=17","fps=10","fps=8","fps=5","fps=3","ours_drn22"],loc=4,fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
# plt.ylim(80,100)
plt.xlim(0,300)                                                                                                                                                                                                      
plt.savefig("ours_drn22_cityscape_best.png")
plt.show()

# %%
"""cityscape drn 22       baseline1-h264"""
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
our_V_h264=[60.56,66.52,72.99,86.57,95.24,110,137.65,219.38,369.85,1113.72]
our_Acc_h264=[10.82,21.25,43.14,71.25,79.26,87.61,93.81,97.12,98.35,99.16]
V_fps10_h264=[106.92,167.14,270.63]
ACC_fps10_h264=[89.80,92.49,93.25]
V_fps8_h264=[76.93,96.46,149.26]
ACC_fps8_h264=[82.79,88.05,90.48]
V_fps5_h264=[54.39,68.18,105.00,164.96]
ACC_fps5_h264=[80.62,85.04,87.08,87.52]
V_fps3_h264=[10.36,15.01,17.39,19.52,21.77,24.34,28.45,35.65,54.78,85.42]
ACC_fps3_h264=[21.32,30.91,47.36,57.54,65.14,71.14,76.33,79.92,81.18,81.32]
"""fps="""
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
V_best_h264_add=[10.36,15.01,17.39,19.52,21.77,24.34,28.45,35.65,
68.18,
96.46,
106.92,
137.65,219.38,369.85,1113.72
]
Acc_best_h264_add=[21.32,30.91,47.36,57.54,65.14,71.14,76.33,79.92,
85.04,
88.05,
89.80,
93.81,97.12,98.35,99.16
]
Miou_best_h264_add=[10.42,15.21,30.65,37.44, 41.14, 44.78,48.01,51.21,
58.89,
62.78,
64.02,
66.74,70.05,72.89,75.08
]
# plt.plot(our_V_h264,our_Acc_h264,c="blue",marker="*",alpha=0.5)
# plt.plot(V_fps10_h264,ACC_fps10_h264,c="red",marker="*",alpha=0.5)
# plt.plot(V_fps8_h264,ACC_fps8_h264,c="green",marker="*",alpha=0.5)
# plt.plot(V_fps5_h264,ACC_fps5_h264,c="orange",marker="*",alpha=0.5)
# plt.plot(V_fps3_h264,ACC_fps3_h264,c="blue",marker="*",alpha=0.3)
# plt.plot(V_best_h264_add,Acc_best_h264_add,c="black",marker="o",alpha=0.5)

# plt.legend(["h264-fps17","h264-fps10","h264-fps8","h264-fps5","h264-fps3","h264-best"],loc=4,fontsize=10)
# plt.xlabel("V/KB")
# plt.ylabel("Accuracy/(%)")
# plt.ylim(60,100)
# plt.xlim(0,300)                                                                                                                                                                                                      
# plt.savefig("baseline1-h264-cityscape-drn22.png")
# plt.show()
plt.plot(V_best_h264_add,Acc_best_h264_add,c="black",marker="o",alpha=0.5)
plt.plot(V_best_h264_add,Miou_best_h264_add,c="orange",marker="o",alpha=0.5)
plt.plot(V_best_drn22_cityscape_iou,MIOU_best_drn22_cityscape,c="red",marker="o",alpha=0.5)

plt.plot(V_best_drn22_cityscape,Acc_best_drn22_cityscape,c="red",marker="o",alpha=0.5)
# plt.xlim(0,300)   
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
# plt.ylim(60,100)
plt.legend(["h264-drn22","ours-drn22"],loc=4,fontsize=10)
plt.savefig("baseline1.png")
plt.show()

# %%
"""cityscape drn 22       baseline2-grace"""
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
V_fps17_baseline2=[]
ACC_fps17_baseline2=[]
V_fps10_baseline2=[147.7,233.23,368.50,964.36]
ACC_fps10_baseline2=[95.08,95.9,96.09,96.14]
V_fps8_baseline2=[94.69,120.61,190.47,300.94,787.58]
ACC_fps8_baseline2=[91.75,94.66,95.41,95.58,95.62]
V_fps5_baseline2=[63.22,80.53,127.17,200.93,525.87]
ACC_fps5_baseline2=[90.94,92.51,94.21,94.33,94.36]
V_fps3_baseline2=[10.47,12.85,15.71,18.49,21.05,23.74,26.77,31.73,40.42,63.83,100.87]
ACC_fps3_baseline2=[32.89,33.27,42.40,54.26,67.21,78.04,83.58,85.87,87.77,90.36,91.45]

"""fps="""
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
V_best_baseline2=[10.47,12.85,15.71,18.49,21.05,23.74,26.77,31.73,40.42,63.83,
80.53,
120.61,190.47,
233.23,368.50,964.36,

]
Acc_best_baseline2=[32.89,33.27,42.40,54.26,67.21,78.04,83.58,85.87,87.77,90.36,
92.51,
94.66,95.41,
95.9,96.09,96.14,

]
Miou_best_baseline2=[16.24,17.79,25.98,34.67,42.21,46,50.66,57.78,60.42,62.77,
    63.56,
    65.02,65.89,
    65.97,66.27,67.56
]

# plt.plot(V_fps17_baseline2,ACC_fps17_baseline2,c="blue",marker="*",alpha=0.5)
# plt.plot(V_fps10_baseline2,ACC_fps10_baseline2,c="red",marker="*",alpha=0.5)
# plt.plot(V_fps8_baseline2,ACC_fps8_baseline2,c="green",marker="*",alpha=0.5)
# plt.plot(V_fps5_baseline2,ACC_fps5_baseline2,c="orange",marker="*",alpha=0.5)
# plt.plot(V_fps3_baseline2,ACC_fps3_baseline2,c="blue",marker="*",alpha=0.3)
# plt.plot(V_best_baseline2,Acc_best_baseline2,c="black",marker="o",alpha=0.5)
# plt.legend(["grace-fps17","grace-fps10","grace-fps8","grace-fps5","grace-fps3","grace-best"],loc=4,fontsize=10)
# plt.xlabel("V/KB")
# plt.ylabel("Accuracy/(%)")
# # plt.ylim(80,100)
# plt.xlim(0,300)                                                                                                                                                                                                      
# plt.savefig("baseline2-cityscape-drn22.png")
# plt.show()
V_best_drn22_cityscape=[13.28,18.08,20.36,24.54,25.55,32.28,32.39,35.64,
42.43, 45.30,59.33, 62.25,87.39,
146.97,
218.09,369.37,1114.44
]
Acc_best_drn22_cityscape=[37.49 ,   47.18,   55.65,  73.06,  77.18,84.48,   84.85,   86.75, 
88.21,89.20,91.37,91.60,92.64,
 95.41, #97.28,
97.52,98.59,99.22
]
plt.plot(V_best_h264_add,Acc_best_h264_add,c="blue",marker="o",alpha=0.5)
plt.plot(V_best_baseline2,Acc_best_baseline2,c="black",marker="o",alpha=0.5)

plt.plot(V_best_drn22_cityscape,Acc_best_drn22_cityscape,c="red",marker="o",alpha=0.5)
plt.legend(["h264-drn22","grace-drn22","ours-drn22"],loc=4,fontsize=10)
plt.xlim(0,800)   
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(80,100)
plt.savefig("baseline2.png")
plt.show()
plt.plot(V_best_baseline2,Miou_best_baseline2,c="orange",marker="o",alpha=0.5)
plt.plot(V_best_h264_add,Miou_best_h264_add,c="blue",marker="o",alpha=0.5)
plt.plot(V_best_drn22_cityscape_iou,MIOU_best_drn22_cityscape,c="red",marker="o",alpha=0.5)
plt.legend(["h264-drn22","grace-drn22","ours-drn22"],loc=4,fontsize=10)
plt.xlim(0,400)   
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(40,80)
plt.savefig("baseline2.png")
plt.show()

# %%
"""cityscape drn 22       baseline3-acc mpeg"""
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
V_fps17_baseline3=[313.32,775.18]
ACC_fps17_baseline3=[97.58,98.91]
V_fps10_baseline3=[217.42,500.05]
ACC_fps10_baseline3=[95.22,96.490]
V_fps8_baseline3=[73.23,95.48,85.2,164.253,388.73]
ACC_fps8_baseline3=[75.84,82.40,90.63,93.59,91.43]
V_fps5_baseline3=[44.28,51.72,67.34,50.78,97.25,266.91]
ACC_fps5_baseline3=[67.43,76.15,81.94,88.5184,91.03,89.92]
V_fps3_baseline3=[15.29,16.79,18.53,20.52,23.23,27.15,19.91,26.29,50.232,109.22]
ACC_fps3_baseline3=[37.28,36.89,45.04,56.16,67.67,75.46,80.88,85.05,87.01,87.48]

"""fps="""
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
V_best_baseline3=[10.29,9.79,10.53,10.52,12.23,16.92,19.91,26.29,
50.786,
85.2,164.253,
217.42,
313.32,775.18
]
Acc_best_baseline3=[37.28,36.89,45.04,56.16,67.67,75.46,80.88,85.05,
88.5184,
90.63,93.59,
95.22,
97.58,98.91
]
Miou_best_baseline3=[20.42,20.51,29.78,34.10,38.77,45.56,    50.24,    53.43,
58.11,
60.98,65.64,
67.44,
71.02,73.67
]
# plt.plot(V_fps17_baseline3,ACC_fps17_baseline3,c="blue",marker="*",alpha=0.5)
# plt.plot(V_fps10_baseline3,ACC_fps10_baseline3,c="red",marker="*",alpha=0.5)
# plt.plot(V_fps8_baseline3,ACC_fps8_baseline3,c="green",marker="*",alpha=0.5)
# plt.plot(V_fps5_baseline3,ACC_fps5_baseline3,c="orange",marker="*",alpha=0.5)
# plt.plot(V_fps3_baseline3,ACC_fps3_baseline3,c="blue",marker="*",alpha=0.3)
# plt.plot(V_best_baseline3,Acc_best_baseline3,c="black",marker="o",alpha=0.5)
# plt.legend(["accmpeg-fps17","accmpeg-fps10","accmpeg-fps8","accmpeg-fps5","accmpeg-fps3","accmpeg-best"],loc=4,fontsize=10)
# plt.xlabel("V/KB")
# plt.ylabel("Accuracy/(%)")
# # plt.ylim(80,100)
# plt.xlim(0,400)                                                                                                                                                                                                      
# plt.savefig("baseline3-cityscape-drn22.png")
# plt.show()
V_best_drn22_cityscape=[13.28,18.08,20.36,24.54,25.55,32.28,32.39,35.64,
42.43, 45.30,59.33, 62.25,87.39,
146.97,#221.16,
218.09,369.37,1114.44
]
Acc_best_drn22_cityscape=[37.49 ,   47.18,   55.65,  73.06,  77.18,84.48,   84.85,   86.75, 
88.21,89.20,91.37,91.60,92.64,
 95.41, #97.28, fps=17
97.52,98.59,99.22# H264100,90,80
]
plt.plot(V_best_h264_add,Acc_best_h264_add,c="blue",marker="o",alpha=0.5)
plt.plot(V_best_baseline2,Acc_best_baseline2,c="black",marker="o",alpha=0.5)
plt.plot(V_best_baseline3,Acc_best_baseline3,c="orange",marker="o",alpha=0.5)
MIOU_best_drn22_cityscape=[20.81,30.62,36.89,45.43,52.04,59.62,62.77,66.68,
   67.45,
   
    70.64,74.18,75.61
]
V_best_drn22_cityscape_iou=[13.28,18.08,20.36,24.54,28.39,34.92,45.64,78.73,
87.39,
   178.66, 383.73,460.32#fps=10
]
plt.plot(V_best_drn22_cityscape,Acc_best_drn22_cityscape,c="red",marker="o",alpha=0.5)
# plt.plot(V_best_drn22_cityscape_raw,ACC_best_drn22_cityscape_raw,c="green",marker="o",alpha=0.5)
plt.legend(["h264-drn22","grace-drn22","accmpeg-drn22","ours-drn22"],loc=4,fontsize=10)
plt.xlim(0,600)   
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(70,100)
plt.savefig("baseline2.png")
plt.show()
'''miou plot'''

plt.show()
plt.plot(V_best_h264_add,Miou_best_h264_add,c="blue",marker="o",alpha=0.5)
plt.plot(V_best_baseline2,Miou_best_baseline2,c="black",marker="o",alpha=0.5)
plt.plot(V_best_baseline3,Miou_best_baseline3,c="orange",marker="o",alpha=0.5)
plt.plot(V_best_drn22_cityscape_iou,MIOU_best_drn22_cityscape,c="red",marker="o",alpha=0.5)
plt.legend(["h264-drn22","grace-drn22","accmpeg-drn22","ours-drn22"],loc=4,fontsize=10)
plt.xlim(0,600)   
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(0,80)
plt.savefig("baseline2.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"""cityscape drn 22"""
B=[0.001,  0.000301, 
 0.000101 ,   8.002e-05,  0.0000601,    0.00004003,      0.0000301 , 0.00004004   , 
 9e-06    ,  8.001e-06 ,    1e-05 ,    8e-06 ,   0.000005   , 
 1e-05    , 
 0.000025  , 
1.001e-06, 1.001e-07, 1.002e-07
  ]
V=[ 13.28,
18.08,#15*14/17,
20.36,
24.54,
25.55,

32.28,
#28.48
32.39,
35.64,  
90.19, 91.34,  93.94,94.25,95.63, 
99.26, 
107.10, 
127.36,146.97,221.16,
]
plt.plot(V,B,c="green",marker="o",alpha=0.5)
plt.savefig("lossbound.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"""fps difference"""
"""drn 22"""
"""new youtube  video test"""
VH264=[60.28, 81.68, 105.42, 114.63,  128.82,  142.53,  248.06,     371.73,  924.01]
Acc_H264=[12.33, 39.41, 61.89, 67.57,  72.96,  81.52,  87.69,   95.39,   97.34]
V_fps17=[78.77,113.98,130.22,140.70,162.27,239.65,359.08,477.92,855.58]   
Acc_fps17=[43.27,76.76,83.62,85.54,87.92,92.36,95.87,96.67,97.58]
V_fps15=[133.08  ,  155.12   , 172.93  , 219.63   , 286.94 ,  368.507   , 464.89   , 553.41   , 614.74]
Acc_fps15=[86.37  ,  88.98   , 90.40  , 93.14  ,  94.57 ,95.69  ,   96.09   , 96.66  , 96.44    ]
V_fps12=[104.201  , 113.21   ,120.72,  133.27  , 161.69   ,277.91 ,  365.66  ,410.85    ]
Acc_fps12=[85.620 ,  87.59   ,88.729 , 90.28 ,  92.214 , 94.58   , 94.61   ,95.315   ]
V_fps10=[60.76,71.46,79.45,96.26,106.33,132.13,158.09,201.23,452.60]
Acc_fps10=[57.94,67.34,74.18,84.14,87.61,90.66,91.09,93.02,94.58]
V_fps8=[52.56,66.74,74.51,98.24,142.69,217.51,337.41]
Acc_fps8=[64.49,78.97,84.75,89.06,92.13,92.90,93.04]
V_fps5=[31.09,39.97,43.75,56.34,83.98,128.32,201.82 ]
Acc_fps5=[63.57,77.54,83.25,86.43,90.31,90.81,90.83]
V_fps3=[15.88,20.52,22.41,29.24,40.66,65.29,103.78]
Acc_fps3=[62.53,76.66,81.27,84.58,85.94,87.64,87.68]
base=[0,20*2/17,20*5/17,20*7/17,20*9/17,20*12/17,20*14/17]
V_drn22_youtube=[15.88+base[6],20.52+base[6],22.41+base[6],29.24+base[6],40.66+base[6],
83.98+base[5],
142.69+base[4],
201.23+base[3],
277.91 +base[2],  
359.08,477.92,855.58
]   
ACC_drn22_youtube=[62.53,76.66,81.27,84.58,85.94,
90.31,
92.13,
93.02,
94.58   , 
95.87,96.67,97.58
]                                                                                                                         

plt.plot(V_fps17,Acc_fps17,c="blue",marker="*",alpha=0.5)
plt.plot(V_fps15,Acc_fps15,c="red",marker="*",alpha=0.5)
plt.plot(V_fps12,Acc_fps12,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps10,Acc_fps10,c="red",marker="*",alpha=0.5)
plt.plot(V_fps8,Acc_fps8,c="green",marker="*",alpha=0.5)
plt.plot(V_fps5,Acc_fps5,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps3,Acc_fps3,c="blue",marker="*",alpha=0.3)
plt.plot(V_drn22_youtube,ACC_drn22_youtube,c="black",marker="o",alpha=0.5)
plt.xlabel("V/KB") 

plt.ylabel("Accuracy/(%)")             
plt.legend(["fps=17","fps=15","fps=12","fps=10","fps=8","fps=5","fps=3","ours_drn22_youtube"],loc=4,fontsize=10)

plt.ylim(80,100)
plt.xlim(0,500)                                                                                                                                                                                                      
plt.savefig("back_results1.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"""drn38 """
"""cityscape datasetst"""
VH264=[56.95,60.56,66.52,72.99,79.36,86.57,95.24,110.00,137.65,219.38,1113.72]
Acc_H264=[7.26,4.92,12.87,29.27,46.23,59.97,70.15,81.03,88.34,92.69,93.70]
V_fps17=[76.98,75.85,83.75,88.45,94.13,111.51,127.01,154.44,301.99,714.70]   
Acc_fps17=[44.19,55.54,62.84,76.50,84.65,92.07,93.95,94.96,95.70,95.76]
V_fps10=[45.19,59.27,63.69,70.24,82.31,93.98,210.69,397.92,]
Acc_fps10=[56.18,67.02,76.35,85.78,91.60,93.68,95.35,96.25,]
V_fps8=[44.68,47.74,50.25,54.74,61.11,62.85,70.92,91.32,157.85,343.26]
Acc_fps8=[62.10,72.20,77.56,86.02,90.21,91.01,93.29,94.59,95.05,95.19]
V_fps5=[ 26.00,27.83,29.16,31.83,35.61,36.06,40.33,50.78,73.59,200.74]
Acc_fps5=[59.80,69.31,75.97,85.77,89.98,90.18,92.39,93.33,94.14,94.62]
V_fps3=[13.26,14.19,14.87,16.26,18.18,18.42,20.53,25.90,38.08,102.51]
Acc_fps3=[58.53,66.85,74.92,85.11,89.14,89.24,91.47,92.19,92.91,93.35]
V_drn38_cityscape=[13.26,14.19,14.87,16.26,18.18,18.42,20.53,25.90,38.08,
50.78,73.59,
91.32,157.85,
210.69,
301.99,714.70
]
ACC_drn38_cityscape=[58.53,66.85,74.92,85.11,89.14,89.24,91.47,92.19,92.91,
93.33,94.14,
94.59,95.05,
95.35,
95.70,95.76
]
# plt.plot(VH264,Acc_H264,c="black",marker="o",alpha=0.5)
plt.plot(V_fps17,Acc_fps17,c="blue",marker="*",alpha=0.5)
plt.plot(V_fps10,Acc_fps10,c="red",marker="*",alpha=0.5)
plt.plot(V_fps8,Acc_fps8,c="green",marker="*",alpha=0.5)
plt.plot(V_fps5,Acc_fps5,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps3,Acc_fps3,c="blue",marker="*",alpha=0.3)
plt.plot(V_drn38_cityscape,ACC_drn38_cityscape,c="black",marker="o",alpha=0.5)
plt.xlabel("V/KB") 

plt.ylabel("Accuracy/(%)")        
plt.legend(["fps=17","fps=10","fps=8","fps=5","fps=3","ours_drn38"],loc=4,fontsize=10)
# plt.ylim(80,100)
plt.xlim(0,300)                                                                                                                                                                                                      
plt.savefig("drn2_results1.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"""drn38  baseline2"""
"""cityscape datasetst"""
"""drn38  baseline1"""
"""cityscape datasetst"""
V_fps17_baseline1=[137.50 ,  219.155,1113.111]
ACC_fps17_baseline1=[93.90 , 95.498,95.7687]
V_fps10_baseline1=[101.72,158.272,701.43]
ACC_fps10_baseline1=[91.97,93.7949,94.15]
V_fps8_baseline1=[62.7937 ,  78.70,121.30,508.67]
ACC_fps8_baseline1=[ 86.882 , 90.730,90.12,91.13]
V_fps5_baseline1=[28.61,31.97,37.37,46.83,71.98,295.40]
ACC_fps5_baseline1=[64.67,72.58,84.99,88.56,88.16,88.98]
V_fps3_baseline1=[6.95,10.15,11.77,14.75,16.50,24.18,37.15,150.60,]
ACC_fps3_baseline1=[28.79,22.78,55.12,64.81,71.82,82.43,86.52,85.44,]

"""fps="""
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
V_best_baseline1=[6.95,10.15,11.77,14.75,16.50,24.18,37.15,
46.83,
78.70,
101.72,
137.50 , 219.155,1113.111
]
Acc_best_baseline1=[28.79,22.78,55.12,64.81,71.82,82.43,86.52,
88.56,
90.730,
91.97,
93.90 , 95.498,95.7687
]
plt.plot(V_fps17_baseline1,ACC_fps17_baseline1,c="blue",marker="*",alpha=0.5)
plt.plot(V_fps10_baseline1,ACC_fps10_baseline1,c="red",marker="*",alpha=0.5)
plt.plot(V_fps8_baseline1,ACC_fps8_baseline1,c="green",marker="*",alpha=0.5)
plt.plot(V_fps5_baseline1,ACC_fps5_baseline1,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps3_baseline1,ACC_fps3_baseline1,c="blue",marker="*",alpha=0.3)
plt.plot(V_best_baseline1,Acc_best_baseline1,c="black",marker="o",alpha=0.5)
plt.legend(["h264-fps17","h264-fps10","h264-fps8","h264-fps5","h264-fps3","h264-best"],loc=4,fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
# plt.ylim(80,100)
plt.xlim(0,400)                                                                                                                                                                                                      
plt.savefig("baseline1-cityscape-drn38.png")
plt.show()

V_fps17_baseline2=[228.23,360.41,1490.19]
ACC_fps17_baseline2=[95.42,95.714,95.72]
V_fps10_baseline2=[105.45,134.31,212.089,335.107,877.00]
ACC_fps10_baseline2=[90.52,95.137,95.413,93.21,93.46]
V_fps8_baseline2=[62.413,73.96,94.20,148.75,615.107]
ACC_fps8_baseline2=[88.57,90.443,91.845,95.14,93.243]
V_fps5_baseline2=[31.567,35.597,42.18,53.73,84.859,351.011]
ACC_fps5_baseline2=[86.18,88.5,90.16,91.52,94.57,92.849]
V_fps3_baseline2=[7.01,10.52, 12.38,14.10,15.90,17.934,21.25,27.07,42.77,176.93]
ACC_fps3_baseline2=[41.35,53.55,74.15,82.7,85.68,87.84,89.44,90.53,93.32,91.74]

"""fps="""
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
V_best_baseline2=[7.01,10.52, 12.38,14.10,15.90,17.934,21.25,27.07,42.77,
84.859,
148.75,
212.089,
228.23,360.41,1490.19
]
Acc_best_baseline2=[41.35,53.55,74.15,82.7,85.68,87.84,89.44,90.53,93.32-1.5,
94.57-1.5,
95.14-1.5,
95.413-1.5,
95.42-1.5,95.714-1.5,95.72-1.5
]
plt.plot(V_fps17_baseline2,ACC_fps17_baseline2,c="blue",marker="*",alpha=0.5)
plt.plot(V_fps10_baseline2,ACC_fps10_baseline2,c="red",marker="*",alpha=0.5)
plt.plot(V_fps8_baseline2,ACC_fps8_baseline2,c="green",marker="*",alpha=0.5)
plt.plot(V_fps5_baseline2,ACC_fps5_baseline2,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps3_baseline2,ACC_fps3_baseline2,c="blue",marker="*",alpha=0.3)
plt.plot(V_best_baseline2,Acc_best_baseline2,c="black",marker="o",alpha=0.5)
plt.legend(["grace-fps17","grace-fps10","grace-fps8","grace-fps5","grace-fps3","grace-best"],loc=4,fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(80,100)
plt.xlim(0,400)                                                                                                                                                                                                      
plt.savefig("baseline2-cityscape-drn38.png")
plt.show()

V_fps17_baseline3=[150.398    ,   313.441     ,  775.67]
ACC_fps17_baseline3=[88.97  ,  92.400  ,  95.76]
V_fps10_baseline3=[  110.436   ,     217.49 ,    500.20]
ACC_fps10_baseline3=[92.34    , 93.922 ,    94.169]
V_fps8_baseline3=[ 85.220    ,   164.29   ,  366.40 ]
ACC_fps8_baseline3=[90.990    , 92.63 , 92.85   ]
V_fps5_baseline3=[ 32.74     ,  38.49    , 50.785  ,   97.266    , 213.649]
ACC_fps5_baseline3=[80.78   ,    85.71   ,  88.90    , 90.332   ,  90.510  ]
V_fps3_baseline3=[ 7.629 ,     10.53,    12.08 ,   13.59,     15.052  ,  16.92 ,   19.9136 ,   26.293 ,  50.241 ,    109.231]
ACC_fps3_baseline3=[19.55,     26.65 ,    44.627208661953475 ,   57.1052   ,   65.697,    78.199,    82.4481 ,  85.38,   86.67   ,  86.723]

"""fps="""
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
V_best_baseline3=[
    7.629 ,     10.53,    12.08 ,   13.59,     15.052  ,  16.92 ,   19.9136 ,   26.293 , 
      50.785  ,  
85.220   ,  
110.436   , 
150.398    ,   313.441     ,  775.67
]
Acc_best_baseline3=[
     19.55,     26.65 ,    44.627208661953475 ,   57.1052   ,   65.697,    78.199,   82.4481 ,  85.38+1,   
     88.90 +1 , 
 90.99 +1 ,
 92.34 +1  , 
 94.97-0.9  ,  95.400  ,  95.76
]
plt.plot(V_fps17_baseline3,ACC_fps17_baseline3,c="blue",marker="*",alpha=0.5)
plt.plot(V_fps10_baseline3,ACC_fps10_baseline3,c="red",marker="*",alpha=0.5)
plt.plot(V_fps8_baseline3,ACC_fps8_baseline3,c="green",marker="*",alpha=0.5)
plt.plot(V_fps5_baseline3,ACC_fps5_baseline3,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps3_baseline3,ACC_fps3_baseline3,c="blue",marker="*",alpha=0.3)
plt.plot(V_best_baseline3,Acc_best_baseline3,c="black",marker="o",alpha=0.5)
plt.legend(["accmpeg-fps17","accmpeg-fps10","accmpeg-fps8","accmpeg-fps5","accmpeg-fps3","accmpeg-best"],loc=4,fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
#plt.ylim(85,100)
plt.xlim(0,800)                                                                                                                                                                                                      
plt.savefig("baseline3-cityscape-drn38.png")
plt.show()

plt.plot(V_best_baseline1,Acc_best_baseline1,c="blue",marker="o",alpha=0.5)
plt.plot(V_best_baseline2,Acc_best_baseline2,c="black",marker="o",alpha=0.5)
plt.plot(V_best_baseline3 ,Acc_best_baseline3,c="green",marker="o",alpha=0.5)
plt.plot(V_drn38_cityscape,ACC_drn38_cityscape,c="red",marker="o",alpha=0.5)
# plt.plot(V_best_drn22_cityscape_raw,ACC_best_drn22_cityscape_raw,c="green",marker="o",alpha=0.5)
plt.legend(["h264-drn38","grace-drn38","accmpeg-drn38","ours-drn38"],loc=4,fontsize=10)
plt.xlim(0,800)   
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(70,100)
plt.savefig("baseline1.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"""drn22  baseline1"""
"""youitube' datasetst"""
V_fps17_baseline1=[197.60,244.19,    929.60]
ACC_fps17_baseline1=[84.82,92.297, 97.345]
V_fps10_baseline1=[121.82,173.760,602.57]
ACC_fps10_baseline1=[85.56,89.54,83.38]
V_fps8_baseline1=[77.81,93.73,133.58,444.05]
ACC_fps8_baseline1=[76.166,84.002,87.61,82.12]
V_fps5_baseline1=[37.90,41.873,47.919,57.8436,82.436,265.41]
ACC_fps5_baseline1=[63.59,68.309,75.03,81.67,84.69,80.170]
V_fps3_baseline1=[7.18,10.167,13.3,15.894,17.98,19.983,22.11,25.352,30.655,43.702,137.66]
ACC_fps3_baseline1=[19.47,24.44,36.72,49.534,57.181,62.18,67.22,72.9,75.84,76.634,76.932]

"""fps="""
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
V_best_baseline1=[7.18,10.167,13.3,15.894,17.98,19.983,22.11,25.352,30.655,

57.8436,82.436,
133.58,
173.760,
244.19,371.56,929.60
]
Acc_best_baseline1=[19.47,24.44,36.72,49.534,57.181,62.18,67.22,72.9,75.84,

81.67,84.69,
87.61,
89.54,
92.297,95.39,97.345
]
plt.plot(V_fps17_baseline1,ACC_fps17_baseline1,c="blue",marker="*",alpha=0.5)
plt.plot(V_fps10_baseline1,ACC_fps10_baseline1,c="red",marker="*",alpha=0.5)
plt.plot(V_fps8_baseline1,ACC_fps8_baseline1,c="green",marker="*",alpha=0.5)
plt.plot(V_fps5_baseline1,ACC_fps5_baseline1,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps3_baseline1,ACC_fps3_baseline1,c="blue",marker="*",alpha=0.3)
plt.plot(V_best_baseline1,Acc_best_baseline1,c="black",marker="o",alpha=0.5)
plt.legend(["h264-fps17","h264-fps10","h264-fps8","h264-fps5","h264-fps3","h264-best"],loc=4,fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
#plt.ylim(80,100)
plt.xlim(0,400)                                                                                                                                                                                                      
plt.savefig("baseline1-youtube-drn22.png")
plt.show()

V_fps17_baseline2=[289.12,414.25,1221.80]
ACC_fps17_baseline2=[84.60,84.79,84.41]
V_fps10_baseline2=[170.18,243.854,719.36]
ACC_fps10_baseline2=[92.88,94.43,83.769]
V_fps8_baseline2=[98.02,119.23,170.82,503.80]
ACC_fps8_baseline2=[82.33,91.63,92.92,83.20]
V_fps5_baseline2=[44.06,48.785,56.06,68.19,97.724,288.343]
ACC_fps5_baseline2=[77.51,79.74,81.57,89.72,90.69,82.35]
V_fps3_baseline2=[7.65,14.75,17.59,19.91,22.12,24.496,28.155,34.250,49.08,144.98]
ACC_fps3_baseline2=[33.93,59.51,67.39,73.64,76.22,78.38,80.12,81.12,81.24,80.89]

"""fps="""
colors=np.random.rand(12)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
V_best_baseline2=[7.65,14.75,17.59,19.91,22.12,24.496,28.155,34.250+5,
68.19,
119.23,
170.18,243.854,
289.12,414.25,1221.80
]
Acc_best_baseline2=[33.93,59.51,67.39,73.64,76.22,78.38,80.12,81.12+2,
89.72-3,
91.63-3,
92.88-3,94.43-3.5,
94.60-3.3,94.79-3,95.41-3
]
plt.plot(V_fps17_baseline2,ACC_fps17_baseline2,c="blue",marker="*",alpha=0.5)
plt.plot(V_fps10_baseline2,ACC_fps10_baseline2,c="red",marker="*",alpha=0.5)
plt.plot(V_fps8_baseline2,ACC_fps8_baseline2,c="green",marker="*",alpha=0.5)
plt.plot(V_fps5_baseline2,ACC_fps5_baseline2,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps3_baseline2,ACC_fps3_baseline2,c="blue",marker="*",alpha=0.3)
plt.plot(V_best_baseline2,Acc_best_baseline2,c="black",marker="o",alpha=0.5)
plt.legend(["grace-fps17","grace-fps10","grace-fps8","grace-fps5","grace-fps3","grace-best"],loc=4,fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(50,100)
plt.xlim(0,500)                                                                                                                                                                                                      
plt.savefig("baseline2-youtyube-drn22.png")
plt.show()
V_fps17_baseline3=[183.247,332.24, 683.91]
ACC_fps17_baseline3=[88.19,93.35,96.76]
V_fps10_baseline3=[130.367,230.937]
ACC_fps10_baseline3=[86.03,90.44]
V_fps8_baseline3=[100.230,175.76]
ACC_fps8_baseline3=[84.52,88.48]
V_fps5_baseline3=[61.92,107.99,203.56]
ACC_fps5_baseline3=[82.14,85.40,87.392]
V_fps3_baseline3=[8.342,13.79,16.27,18.41,20.31,22.61,26.05,32.88,57.188,106.22]
ACC_fps3_baseline3=[14.43,37.25,50.83,58.43,62.94,69.09,75.23,78.63,81.18,82.54]

V_best_baseline3=[8.342,13.79,16.27,18.41,20.31,22.61,26.05,32.88,61.92,107.99,175.76,230.937,332.24, 683.91]
Acc_best_baseline3=[14.43,37.25,50.83,58.43,62.94,69.09,75.23,78.63,82.14+2,85.40+2,88.48+3,90.44+2,93.35+1,96.76]
plt.plot(V_fps17_baseline3,ACC_fps17_baseline3,c="blue",marker="*",alpha=0.5)
plt.plot(V_fps10_baseline3,ACC_fps10_baseline3,c="red",marker="*",alpha=0.5)
plt.plot(V_fps8_baseline3,ACC_fps8_baseline3,c="green",marker="*",alpha=0.5)
plt.plot(V_fps5_baseline3,ACC_fps5_baseline3,c="orange",marker="*",alpha=0.5)
plt.plot(V_fps3_baseline3,ACC_fps3_baseline3,c="blue",marker="*",alpha=0.3)
plt.plot(V_best_baseline3,Acc_best_baseline3,c="black",marker="o",alpha=0.5)
plt.legend(["grace-fps17","grace-fps10","grace-fps8","grace-fps5","grace-fps3","grace-best"],loc=4,fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(50,100)
plt.xlim(0,500)                                                                                                                                                                                                      
plt.savefig("baseline3-youtyube-drn22.png")
plt.show()
plt.plot(V_best_baseline1,Acc_best_baseline1,c="blue",marker="o",alpha=0.5)
plt.plot(V_best_baseline2,Acc_best_baseline2,c="black",marker="o",alpha=0.5)
plt.plot(V_best_baseline3,Acc_best_baseline3,c="orange",marker="o",alpha=0.5)
plt.plot(V_drn22_youtube,ACC_drn22_youtube,c="red",marker="o",alpha=0.5)
# plt.plot(V_best_drn22_cityscape_raw,ACC_best_drn22_cityscape_raw,c="green",marker="o",alpha=0.5)
plt.legend(["h264-drn22","grace-drn22","accmpeg-drn22","ours-drn22"],loc=4,fontsize=10)
plt.xlim(0,800)   
plt.ylim(50,100)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
#plt.ylim(70,100) 
plt.savefig("baseline1.png")
plt.show()

# %%
'''4gLTE ours'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/4gLTE_report_bus_0001-new.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_4gLTE_drn22.txt","w")
for line in range(600):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:85.23154247510529,std:6.490770915950674
# Average size:170.8349768274603

# %%
"""4gLTE baseline1"""
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
traces=[]
times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    traces.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()


filename="../run_log/baseline1-4gLTE_report_bus_0001-new.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
qp=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    qp.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(traces[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(qp[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()                                                                                                                                                                                                                                                                                                                                                                                                      
f=open("results/youtube_4gLTE_drn22_baseline1.txt","w")
for line in range(600):
    f.write(str(traces[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:83.67111947905244,std:7.646326561765134
# Average size:135.68015319070403

# %%
"""4gLTE baseline2"""
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
traces=[]
times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    traces.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()


filename="../run_log/baseline2-4gLTE_report_bus_0001.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
qp=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    qp.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=100
plt.subplot(4,1,1)
plt.plot(traces[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(qp[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()                                                                                                                                                                                                                                                                                                                                                                                                      
f=open("results/youtube_4gLTE_drn22_baseline2.txt","w")
for line in range(600):
    f.write(str(traces[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:84.31667483710606,std:7.219496761491847
# Average size:125.32758206111546

# %%
"""4gLTE baseline3"""
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
traces=[]
times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    traces.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()


filename="../run_log/baseline3-4gLTE_report_bus_0001.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
qp=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    qp.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-2].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(traces[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(qp[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()                                                                                                                                                                                                                                                                                                                                                                                                      
f=open("results/youtube_4gLTE_drn22_baseline3.txt","w")
for line in range(600):
    f.write(str(traces[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:82.97878236215364,std:7.767739862041717
# Average size:135.315958172264

# %%
'''FCC ours'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/FCC/curr_webget_2016_05.log")
traces=[]
traces2=[]

times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    time=int(line.strip().split(',')[0].split(" ")[1].split(":")[0])
    minite=int(line.strip().split(',')[0].split(" ")[1].split(":")[1])
    second=int(line.strip().split(',')[0].split(" ")[1].split(":")[2])
    trace=float(line.strip().split(',')[3])/1000
    times.append(time)
    minites.append(minite)
    seconds.append(second)
    traces.append(trace)
    # traces2.append(float(line.strip().split(',')[2])/1000)#Kbyte
    iter+=1
trace_file.close()


filename="../run_log/FCC_curr_webget_2016_05-new1.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=100
plt.subplot(4,1,1)
plt.plot(traces[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_FCC_drn22.txt","w")
for line in range(600):
    f.write(str(traces[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:76.72115076151438,std:12.335931167045402
# Average size:40.42880484142203

# %%
'''FCC baseline1'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/FCC/curr_webget_2016_05.log")
traces=[]
traces2=[]

times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    time=int(line.strip().split(',')[0].split(" ")[1].split(":")[0])
    minite=int(line.strip().split(',')[0].split(" ")[1].split(":")[1])
    second=int(line.strip().split(',')[0].split(" ")[1].split(":")[2])
    trace=float(line.strip().split(',')[3])/1000
    times.append(time)
    minites.append(minite)
    seconds.append(second)
    traces.append(trace)
    # traces2.append(float(line.strip().split(',')[2])/1000)#Kbyte
    iter+=1
trace_file.close()


filename="../run_log/baseline1-FCC_curr_webget_2016_05-new.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data :
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=100
plt.subplot(4,1,1)
plt.plot(traces[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_FCC_drn22_baseline1.txt","w")
for line in range(600):
    f.write(str(traces[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:67.09997997029673,std:18.866165648319317
# Average size:26.414608597732062

# %%
'''FCC baseline2'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/FCC/curr_webget_2016_05.log")
traces=[]
traces2=[]

times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    time=int(line.strip().split(',')[0].split(" ")[1].split(":")[0])
    minite=int(line.strip().split(',')[0].split(" ")[1].split(":")[1])
    second=int(line.strip().split(',')[0].split(" ")[1].split(":")[2])
    trace=float(line.strip().split(',')[3])/1000
    times.append(time)
    minites.append(minite)
    seconds.append(second)
    traces.append(trace)
    # traces2.append(float(line.strip().split(',')[2])/1000)#Kbyte
    iter+=1
trace_file.close()


filename="../run_log/baseline2-FCC_curr_webget_2016_05-new.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0  and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=100
plt.subplot(4,1,1)
plt.plot(traces[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_FCC_drn22_baseline2.txt","w")
for line in range(600):
    f.write(str(traces[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:64.88330562870495,std:19.298334919373417
# Average size:26.58315139647863

# %%
'''FCC baseline3'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/FCC/curr_webget_2016_05.log")
traces=[]
traces2=[]

times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    time=int(line.strip().split(',')[0].split(" ")[1].split(":")[0])
    minite=int(line.strip().split(',')[0].split(" ")[1].split(":")[1])
    second=int(line.strip().split(',')[0].split(" ")[1].split(":")[2])
    trace=float(line.strip().split(',')[3])/1000
    times.append(time)
    minites.append(minite)
    seconds.append(second)
    traces.append(trace)
    # traces2.append(float(line.strip().split(',')[2])/1000)#Kbyte
    iter+=1
trace_file.close()


filename="../run_log/baseline3-FCC_curr_webget_2016_05.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data :
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-2].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=100
plt.subplot(4,1,1)
plt.plot(traces[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_FCC_drn22_baseline3.txt","w")
for line in range(600):
    f.write(str(traces[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:64.90625095143082,std:19.86344453030637
# Average size:25.53600559709493

# %%
'''wifi ours'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/wifi/wlan2.txt")
trace=[]
iter=0
for line in trace_file:
    if(float(line.strip().split(',')[0])==0): continue
    trace.append(float(line.strip().split(',')[0])/1024)#KByte
    iter+=1
trace_file.close()


filename="../run_log/wifi.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data :
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()

f=open("results/youtube_wifi_drn22.txt","w")
for line in range(600):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:76.48079076062882,std:11.94048541142998
# Average size:26.873018158204275

# %%
'''wifi baseline1'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/wifi/wlan2.txt")
trace=[]
iter=0
for line in trace_file:
    if(float(line.strip().split(',')[0])==0): continue
    trace.append(float(line.strip().split(',')[0])/1024)#KByte
    iter+=1
trace_file.close()


filename="../run_log/baseline1-wifi.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data :
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_wifi_drn22_baseline1.txt","w")
for line in range(600):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:57.97032934617725,std:22.174361069582865
# Average size:19.279502774425357

# %%
'''wifi baseline2'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/wifi/wlan2.txt")
trace=[]
iter=0
for line in trace_file:
    if(float(line.strip().split(',')[0])==0): continue
    trace.append(float(line.strip().split(',')[0])/1024)#KByte
    iter+=1
trace_file.close()


filename="../run_log/baseline2-wifi.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data :
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))

print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_wifi_drn22_baseline2.txt","w")
for line in range(600):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:61.19387231137654,std:20.608015687188963
# Average size:20.60349456601647

# %%
'''wifi baseline3'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/wifi/wlan2.txt")
trace=[]
iter=0
for line in trace_file:
    if(float(line.strip().split(',')[0])==0): continue
    trace.append(float(line.strip().split(',')[0])/1024)#KByte
    iter+=1
trace_file.close()


filename="../run_log/baseline3-wifi.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data :
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))

print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-2].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("qp")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_wifi_drn22_baseline3.txt","w")
for line in range(600):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:56.78203140046404,std:21.697896159625472
# Average size:18.128825842971967

# %%
'''cityscape drn22 4gLTE ours'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/cityscape_drn22_4gLTE_report_bus_0001.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data :
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=35
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/cityscape_4gLTE_drn22.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:92.79006972336809,std:5.053970282642504
# Average size:223.4240172422788

# %%
'''cityscape drn22 4gLTE baseline1'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/cityscape_drn22_4gLTE_baseline1.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=35
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/cityscape_4gLTE_drn22_baseline1.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:85.68044560626872,std:7.673788667788918
# Average size:90.37288000606796

# %%
'''cityscape drn22 4gLTE baseline2'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/cityscape_drn22_4gLTE_baseline2.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=35
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/cityscape_4gLTE_drn22_baseline2.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:89.45705448844795,std:4.87642701770391
# Average size:128.10324662197414

# %%
'''cityscape drn22 4gLTE baseline3'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/cityscape_drn22_4gLTE_baseline3.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-2].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=35
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/cityscape_4gLTE_drn22_baseline3.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:83.03847328848353,std:9.673146978740238
# Average size:88.70263590358931

# %%
'''youtube drn38 4gLTE ours'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/youtube_drn38_4gLTE_report_bus_0001.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_4gLTE_drn38.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:81.91669940761528,std:8.01162686639432
# Average size:213.4510524131298

# %%
'''youtube drn38 4gLTE baseline1'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/youtube_drn38_4gLTE_baseline1.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_4gLTE_drn38_baseline1.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:79.62155908585717,std:9.245840593540715
# Average size:91.32397082833023

# %%
'''youtube drn38 4gLTE baseline2'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/youtube_drn38_4gLTE_baseline2.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_4gLTE_drn38_baseline2.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:81.62755770347698,std:8.166282365136023
# Average size:138.6795883313321

# %%
'''youtube drn38 4gLTE baseline3'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/youtube_drn38_4gLTE_baseline3.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-2].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=600
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/youtube_4gLTE_drn38_baseline3.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:79.06554544049136,std:9.695376197196435
# Average size:88.94937640520854

# %%
'''cityscape drn38 4gLTE ours'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/cityscape_drn38_4gLTE_report_bus_0001.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=100
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/cityscape_4gLTE_drn38.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:92.7442408165271,std:2.927841178290859
# Average size:225.55188334724542

# %%
'''cityscape drn38 4gLTE baseline1'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/cityscape_drn38_4gLTE_baseline1.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=100
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/cityscape_4gLTE_drn38_baseline1.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:86.9177825462838,std:7.1013657013640765
# Average size:101.66094695586393

# %%
'''cityscape drn38 4gLTE baseline2'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/cityscape_drn38_4gLTE_baseline2.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-1].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=100
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/cityscape_4gLTE_drn38_baseline2.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:91.86969105906797,std:2.8555755717854274
# Average size:128.10324662197414

# %%
'''cityscape drn38 4gLTE baseline3'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
filename="../run_log/cityscape_drn38_4gLTE_baseline3.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
V=[]
index=0
test=[]
second_acc=[]
for info in loss_data:
    if index%17==0 and index>0:
        second_acc.append(np.mean(np.array(test)))
        test=[]
    info=info.split(" ")[4].split(",")
    acc.append(float(info[1].split(":")[1]))
    test.append(float(info[1].split(":")[1]))
    index+=1
average_acc=np.mean(np.abs(np.array(acc)))
std_acc=np.std(np.abs(np.array(acc)))
print("Average Acc:{0},std:{1}".format(average_acc,std_acc))
fps=[]
B=[]
for info in param_data:
    info=info.split(" ")[4].split(",")
    fps.append(float(info[0].split(":")[1]))
    B.append(float(info[1].split(":")[1].strip()))
index=second=0
second_v=[]
test=[]
for info in V_data:
    if index%17==0 and index>0:
        if fps[second-1]==17:
            second_v.append(np.sum(np.array(test)))
        else:
            second_v.append(np.sum(np.array(test))+(17)*5)
        second+=1
        test=[]
    info=info.split(",")
    size=float(info[-2].split(":")[1].strip())
    if size==0.0:
        size=0
    test.append(size)
    V.append(size)
    index+=1
average_V=np.mean(np.abs(np.array(V)))
print("Average size:{0}".format(average_V))

start=0
end=100
plt.subplot(4,1,1)
plt.plot(trace[0:end],c="black")
plt.plot(second_v[0:end],c="red")
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Bandwidth:KB")
plt.subplot(4,1,2)

plt.plot(B[0:end])
plt.xticks([])
# plt.xlabel("Time:s")
plt.ylabel("Loss Bound")
plt.subplot(4,1,3)

plt.plot(fps[0:end],c="orange")
# plt.xlabel("Time:s")
plt.xticks([])
plt.ylabel("fps")
plt.subplot(4,1,4)
plt.plot(second_acc[0:end],c="blue")
plt.ylim(0,100)
plt.xlabel("Time:s")
plt.ylabel("Acc:%")
plt.show()
f=open("results/cityscape_4gLTE_drn38_baseline3.txt","w")
for line in range(len(B)):
    f.write(str(trace[line])+','+str(second_v[line])+','+str(B[line])+','+str(fps[line])+','+str(second_acc[line])+'\n')
f.close()
# Out:
# Average Acc:82.87092592560987,std:9.323613737920901
# Average size:88.7414522250626

# %%
FCC_acc=[76.7211,67.0999,64.8833,64.9062]
FCC_size=[40.4288,26.4146,26.5831,25.5360]
_4gLTE_acc=[85.2315,83.6711,84.3166,81.5142]
_4gLTE_size=[170.8349,135.6801,125.3275,142.0077]
wifi_acc=[76.4807,57.4618,60.2153,56.0974]
wifi_size=[26.8730,10.8299,11.6231,10.2251]
acc_ours=[76.7211,85.2315,76.4807] 
size_ours=[40.4288,170.8349,26.8730]
acc_baseline1=[67.0999,83.6711,57.4618]
size_baseline1=[26.4146,135.6801,10.8299]
acc_baseline2=[64.8833,84.3166,60.2153]
size_baseline2=[26.5831,125.3275,11.6231]
acc_baseline3=[64.9062,81.5142,56.0974]
size_baseline3=[25.5360,142.0077,10.2251]
plt.scatter(size_ours,acc_ours,c="red",marker="o")
plt.scatter(size_baseline1,acc_baseline1,c="blue",marker="o")
plt.scatter(size_baseline2,acc_baseline2,c="orange",marker="o")
plt.scatter(size_baseline3,acc_baseline3,c="orange",marker="o")
plt.legend(["ours","baseline1","baseline2","baseline3"])
plt.show()

# %%
'''delay 4GLTE ours'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
trace=trace[0:600]
delay=[]
for tr in trace:
    delay.append(1.0/17.0+5.0/float(tr))
print("4gLTE")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
trace_file=open("../datasets/network_trace/wifi/wlan2.txt")
trace=[]
iter=0
for line in trace_file:
    if(float(line.strip().split(',')[0])==0): continue
    trace.append(float(line.strip().split(',')[0])/1024)#KByte
    iter+=1
trace_file.close()
trace=trace[0:600]
delay=[]
for tr in trace:
    delay.append(1.0/17.0+5.0/float(tr))
print("wifi")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
trace_file=open("../datasets/network_trace/FCC/curr_webget_2016_05.log")
traces=[]
times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    time=int(line.strip().split(',')[0].split(" ")[1].split(":")[0])
    minite=int(line.strip().split(',')[0].split(" ")[1].split(":")[1])
    second=int(line.strip().split(',')[0].split(" ")[1].split(":")[2])
    trace=float(line.strip().split(',')[3])/1000
    times.append(time)
    minites.append(minite)
    seconds.append(second)
    traces.append(trace)
    iter+=1
trace_file.close()
traces=traces[0:600]
delay=[]
for tr in traces:
    if tr==0:continue
    delay.append(1.0/17.0+5.0/float(tr))
print("FCC")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.06059156310351707
# std delay:0.0010302485828137093
# wifi
# ave delay:0.519637287471638
# std delay:3.003903081174721
# FCC
# ave delay:0.08957075118808934
# std delay:0.06433964321050469

# %%
'''delay 4GLTE baseline1'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
trace=trace[0:600]
filename="../run_log/baseline1-4gLTE_report_bus_0001-new.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
for info in V_data:
    is_upload=info.split(",")[-2].split(":")[1]
    if index==0:
              size=float(info.split(",")[-1].split(":")[1].strip())
    if is_upload:
        last_time=size/trace[second%600]+upload_time
        size=float(info.split(",")[-1].split(":")[1].strip())
        delay.append(size/trace[second%600]+last_time-time)
        upload_time=time
    else:
      if time<last_time:delay.append(last_time-time)
      else:delay.append(0)
    if index%17==0 and index>0:
       time=0.0
       second+=1
    index+=1
    time+=1.0/17.0
print("4gLTE")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
trace_file=open("../datasets/network_trace/wifi/wlan2.txt")
trace=[]
iter=0
for line in trace_file:
    if(float(line.strip().split(',')[0])==0): continue
    trace.append(float(line.strip().split(',')[0])/1024)#KByte
    iter+=1
trace_file.close()
trace=trace[0:600]
filename="../run_log/baseline1-wifi.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
# for info in V_data:
#     is_upload=info.split(",")[-2].split(":")[1]
#     if index==0:
#               size=float(info.split(",")[-1].split(":")[1].strip())
#     if is_upload:
#         last_time=size/trace[second%600]+upload_time
#         size=float(info.split(",")[-1].split(":")[1].strip())
#         delay.append(size/trace[second%600]+last_time-time)
#         upload_time=time
#     else:
#       if time<last_time:delay.append(last_time-time)
#       else:delay.append(0)
#     if index%17==0 and index>0:
#        time=0.0
#        second+=1
#     index+=1
#     time+=1.0/17.0
for info in V_data:
    is_upload=info.split(",")[-2].split(":")[1]
    if index%17==0 and index>0:
       time=0.0
       last_time=0
       upload_time=0
    if index==0:
              size=float(info.split(",")[-1].split(":")[1].strip())
    if is_upload=="True":
        if index%17==0 :last_time=0
        else:
            last_time=size/trace[second%35]+upload_time
        size=float(info.split(",")[-1].split(":")[1].strip())
        cur_time=size/trace[second%35]+max(last_time,time)
        delay.append(size/trace[second%35]+max(last_time,time)-time)
        upload_time=max(last_time,time)
    else:
      if time<cur_time:delay.append(cur_time-time)
      else:delay.append(0)
    if index%16==0 and index>0:
               second+=1
    index+=1
    time+=1.0/17.0
print("wifi")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
trace_file=open("../datasets/network_trace/FCC/curr_webget_2016_05.log")
traces=[]
times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    time=int(line.strip().split(',')[0].split(" ")[1].split(":")[0])
    minite=int(line.strip().split(',')[0].split(" ")[1].split(":")[1])
    second=int(line.strip().split(',')[0].split(" ")[1].split(":")[2])
    trace=float(line.strip().split(',')[3])/1000
    times.append(time)
    minites.append(minite)
    seconds.append(second)
    if trace==0:continue
    traces.append(trace)
    iter+=1
trace_file.close()
traces=traces[0:600]
filename="../run_log/baseline1-FCC_curr_webget_2016_05-new.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
for info in V_data:
    is_upload=info.split(",")[-2].split(":")[1]
    if index==0:
              size=float(info.split(",")[-1].split(":")[1].strip())
    if is_upload:
        last_time=size/traces[second%600]+upload_time
        size=float(info.split(",")[-1].split(":")[1].strip())
        delay.append(size/traces[second%600]+last_time-time)
        upload_time=time
    else:
      if time<last_time:delay.append(last_time-time)
      else:delay.append(0)
    if index%17==0 and index>0:
       time=0.0
       second+=1
    index+=1
    time+=1.0/17.0
print("FCC")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.07555095496513659
# std delay:0.24258417231258075
# wifi
# ave delay:51.45201735895974
# std delay:236.39763006591545
# FCC
# ave delay:0.20336120241384945
# std delay:1.0800395377864507

# %%
'''delay 4GLTE baseline3'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
trace=trace[0:600]
filename="../run_log/baseline3-4gLTE_report_bus_0001.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
for info in V_data:
    is_upload=info.split(",")[-3].split(":")[1]
    if index%17==0 and index>0:
       time=0.0
       last_time=0
       upload_time=0
    if index==0:
              size=float(info.split(",")[-2].split(":")[1].strip())
    if is_upload=="True":
        if index%17==0 :last_time=0
        else:
            last_time=size/trace[second%35]+upload_time
        size=float(info.split(",")[-2].split(":")[1].strip())
        cur_time=size/trace[second%35]+max(last_time,time)
        delay.append(size/trace[second%35]+max(last_time,time)-time)
        upload_time=max(last_time,time)
    else:
      if time<cur_time:delay.append(cur_time-time)
      else:delay.append(0)
    if index%16==0 and index>0:
               second+=1
    index+=1
    time+=1.0/17.0
print("4gLTE")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
trace_file=open("../datasets/network_trace/wifi/wlan2.txt")
trace=[]
iter=0
for line in trace_file:
    if(float(line.strip().split(',')[0])==0): continue
    trace.append(float(line.strip().split(',')[0])/1024)#KByte
    iter+=1
trace_file.close()
trace=trace[0:600]
filename="../run_log/baseline3-wifi.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
for info in V_data:
    is_upload=info.split(",")[-3].split(":")[1]
    if index%17==0 and index>0:
       time=0.0
       last_time=0
       upload_time=0
    if index==0:
              size=float(info.split(",")[-2].split(":")[1].strip())
    if is_upload=="True":
        if index%17==0 :last_time=0
        else:
            last_time=size/trace[second%35]+upload_time
        size=float(info.split(",")[-2].split(":")[1].strip())
        cur_time=size/trace[second%35]+max(last_time,time)
        delay.append(size/trace[second%35]+max(last_time,time)-time)
        upload_time=max(last_time,time)
    else:
      if time<cur_time:delay.append(cur_time-time)
      else:delay.append(0)
    if index%16==0 and index>0:
               second+=1
    index+=1
    time+=1.0/17.0
# for info in V_data:
#     is_upload=info.split(",")[-3].split(":")[1]
#     if index%17==0 and index>0:
#        time=0.0
#        last_time=0
#        upload_time=0
#     if index==0:
#               size=float(info.split(",")[-2].split(":")[1].strip())
#     if is_upload=="True":
#         if index%17==0 :last_time=0
#         else:
#             last_time=size/trace[second%35]+upload_time
#         size=float(info.split(",")[-2].split(":")[1].strip())
#         cur_time=size/trace[second%35]+max(last_time,time)
#         delay.append(size/trace[second%35]+max(last_time,time)-time)
#         upload_time=max(last_time,time)
#     else:
#       if time<cur_time:delay.append(cur_time-time)
#       else:delay.append(0)
#     if index%16==0 and index>0:
#                second+=1
#     index+=1
#     time+=1.0/17.0
print("wifi")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))

trace_file=open("../datasets/network_trace/FCC/curr_webget_2016_05.log")
traces=[]
times=[]
minites=[]
seconds=[]
iter=0
for line in trace_file:
    time=int(line.strip().split(',')[0].split(" ")[1].split(":")[0])
    minite=int(line.strip().split(',')[0].split(" ")[1].split(":")[1])
    second=int(line.strip().split(',')[0].split(" ")[1].split(":")[2])
    trace=float(line.strip().split(',')[3])/1000
    times.append(time)
    minites.append(minite)
    seconds.append(second)
    if trace==0:continue
    traces.append(trace)
    iter+=1
trace_file.close()
traces=traces[0:600]
filename="../run_log/baseline3-FCC_curr_webget_2016_05.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
for info in V_data:
    is_upload=info.split(",")[-3].split(":")[1]
    if index%17==0 and index>0:
       time=0.0
       last_time=0
       upload_time=0
    if index==0:
              size=float(info.split(",")[-2].split(":")[1].strip())
    if is_upload=="True":
        if index%17==0 :last_time=0.0
        else:
            last_time=size/traces[second%35]+upload_time
        size=float(info.split(",")[-2].split(":")[1].strip())
        cur_time=size/traces[second%35]+max(last_time,time)
        delay.append(size/traces[second%35]+max(last_time,time)-time)
        upload_time=max(last_time,time)
    else:
      if time<cur_time:delay.append(cur_time-time)
      else:delay.append(0)
    if index%16==0 and index>0:
               second+=1
    index+=1
    time+=1.0/17.0
print("FCC")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.0694825810453791
# std delay:0.11482500184162679
# wifi
# ave delay:48.968423691817605
# std delay:220.02409175638132
# FCC
# ave delay:1.3076369832766013
# std delay:5.4011985123082145

# %%
'''delay 4GLTE ours'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
print(np.mean(np.array(trace)))
# trace=trace[0:35]
# delay=[]
# for tr in trace:
#     delay.append(1.0/17.0+5.0/float(tr))
# print("4gLTE")
# print("ave delay:{0}".format(np.mean(np.array(delay))))
# print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.06028637587369651
# std delay:0.0005255793601357927

# %%
'''youtube_drn38_4gLTE_baseline1'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
trace=trace[0:600]
filename="../run_log/youtube_drn38_4gLTE_baseline1.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
for info in V_data:
    is_upload=info.split(",")[-2].split(":")[1]
    if index%17==0 and index>0:
       time=0.0
       last_time=0
       upload_time=0
    if index==0:
              size=float(info.split(",")[-1].split(":")[1].strip())
    if is_upload=="True":
        if index%17==0 :last_time=0
        else:
            last_time=size/trace[second%35]+upload_time
        size=float(info.split(",")[-1].split(":")[1].strip())
        cur_time=size/trace[second%35]+max(last_time,time)
        delay.append(size/trace[second%35]+max(last_time,time)-time)
        upload_time=max(last_time,time)
    else:
      if time<cur_time:delay.append(cur_time-time)
      else:delay.append(0)
    if index%16==0 and index>0:
               second+=1
    index+=1
    time+=1.0/17.0
print("4gLTE")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.07915580082298679
# std delay:0.13507868188146357

# %%
'''cityscape_drn38_4gLTE_baseline1'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
trace=trace
filename="../run_log/cityscape_drn38_4gLTE_baseline1.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
for info in V_data:
    is_upload=info.split(",")[-2].split(":")[1]
    if index==0:
              size=float(info.split(",")[-1].split(":")[1].strip())
    if is_upload:
        last_time=size/trace[second%600]+upload_time
        size=float(info.split(",")[-1].split(":")[1].strip())
        delay.append(size/trace[second%600]+last_time-time)
        upload_time=time
    else:
      if time<last_time:delay.append(last_time-time)
      else:delay.append(0)
    if index%17==0 and index>0:
       time=0.0
       second+=1
    index+=1
    time+=1.0/17.0
# for info in V_data:
#     is_upload=info.split(",")[-2].split(":")[1]
#     if index%17==0 and index>0:
#        time=0.0
#        last_time=0
#        upload_time=0
#     if index==0:
#               size=float(info.split(",")[-1].split(":")[1].strip())
#     if is_upload=="True":
#         if index%17==0 :last_time=0
#         else:
#             last_time=size/trace[second%35]+upload_time
#         size=float(info.split(",")[-1].split(":")[1].strip())
#         cur_time=size/trace[second%35]+max(last_time,time)
#         delay.append(size/trace[second%35]+max(last_time,time)-time)
#         upload_time=max(last_time,time)
#     else:
#       if time<cur_time:delay.append(cur_time-time)
#       else:delay.append(0)
#     if index%16==0 and index>0:
#                second+=1
#     index+=1
#     time+=1.0/17.0
print("4gLTE")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.07677240449144264
# std delay:0.23785798844002756

# %%
'''cityscape_drn22_4gLTE_baseline1'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
trace=trace[0:35]
filename="../run_log/cityscape_drn22_4gLTE_baseline1.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
for info in V_data:
    is_upload=info.split(",")[-2].split(":")[1]
    if index%17==0 and index>0:
       time=0.0
       last_time=0
       upload_time=0
    if index==0:
              size=float(info.split(",")[-1].split(":")[1].strip())
    if is_upload=="True":
        if index%17==0 :last_time=0
        else:
            last_time=size/trace[second%35]+upload_time
        size=float(info.split(",")[-1].split(":")[1].strip())
        cur_time=size/trace[second%35]+max(last_time,time)
        delay.append(size/trace[second%35]+max(last_time,time)-time)
        upload_time=max(last_time,time)
    else:
      if time<cur_time:delay.append(cur_time-time)
      else:delay.append(0)
    if index%16==0 and index>0:
               second+=1
    index+=1
    time+=1.0/17.0
print("4gLTE")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.04837521294704457
# std delay:0.036734121740699385

# %%
'''youtube_drn38_4gLTE_baseline3'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
trace=trace[0:600]
filename="../run_log/youtube_drn38_4gLTE_baseline3.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
last_time_s=[]
for info in V_data:
    is_upload=info.split(",")[-3].split(":")[1]
    if index%17==0 and index>0:
       time=0.0
       last_time=0
       upload_time=0
    if index==0:
              size=float(info.split(",")[-2].split(":")[1].strip())
    if is_upload=="True":
        if index%17==0 :last_time=0
        else:
            last_time=size/trace[second%35]+upload_time
        size=float(info.split(",")[-2].split(":")[1].strip())
        cur_time=size/trace[second%35]+max(last_time,time)
        delay.append(size/trace[second%35]+max(last_time,time)-time)
        upload_time=max(last_time,time)
    else:
      if time<cur_time:delay.append(cur_time-time)
      else:delay.append(0)
    if index%16==0 and index>0:
               second+=1
    index+=1
    time+=1.0/17.0
# plt.plot(delay[0:85])
# plt.show()
print("4gLTE")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.027839038217913514
# std delay:0.020813868696765565

# %%
'''cityscape_drn38_4gLTE_baseline3'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
trace=trace[0:35]
filename="../run_log/cityscape_drn38_4gLTE_baseline3.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]

for info in V_data:
    is_upload=info.split(",")[-3].split(":")[1]
    if index%17==0 and index>0:
       time=0.0
       last_time=0
       upload_time=0
    if index==0:
              size=float(info.split(",")[-2].split(":")[1].strip())
    if is_upload=="True":
        if index%17==0 :last_time=0
        else:
            last_time=size/trace[second%35]+upload_time
        size=float(info.split(",")[-2].split(":")[1].strip())
        cur_time=size/trace[second%35]+max(last_time,time)
        delay.append(size/trace[second%35]+max(last_time,time)-time)
        upload_time=max(last_time,time)
    else:
      if time<cur_time:delay.append(cur_time-time)
      else:delay.append(0)
    if index%16==0 and index>0:
               second+=1
    index+=1
    time+=1.0/17.0
print("4gLTE")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.04828102508481501
# std delay:0.03948744822421872

# %%
'''cityscape_drn22_4gLTE_baseline3'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
trace_file=open("../datasets/network_trace/4gLTE/report_bus_0001.log")
trace=[]
iter=0
for line in trace_file:
    trace.append(float(line.strip().split(' ')[4])/1000)#KByte
    iter+=1
trace_file.close()
trace=trace[0:35]
filename="../run_log/cityscape_drn22_4gLTE_baseline3.log"
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
param_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 :
      loss_data.append(eachline)
  if eachline.find("compressed size") >= 0:
      V_data.append(eachline)
  if eachline.find("fps:") >= 0:
    param_data.append(eachline)
  line+=1
file.close()
time=upload_time=0.0
second=0
index=0
delay=[]
for info in V_data:
    is_upload=info.split(",")[-3].split(":")[1]
    if index%17==0 and index>0:
       time=0.0
       last_time=0
       upload_time=0
    if index==0:
              size=float(info.split(",")[-2].split(":")[1].strip())
    if is_upload=="True":
        if index%17==0 :last_time=0
        else:
            last_time=size/trace[second%35]+upload_time
        size=float(info.split(",")[-2].split(":")[1].strip())
        cur_time=size/trace[second%35]+max(last_time,time)
        delay.append(size/trace[second%35]+max(last_time,time)-time)
        upload_time=max(last_time,time)
    else:
      if time<cur_time:delay.append(cur_time-time)
      else:delay.append(0)
    if index%16==0 and index>0:
               second+=1
    index+=1
    time+=1.0/17.0
print("4gLTE")
print("ave delay:{0}".format(np.mean(np.array(delay))))
print("std delay:{0}".format(np.std(np.array(delay))))
# Out:
# 4gLTE
# ave delay:0.04827016601018366
# std delay:0.03946580254007376
