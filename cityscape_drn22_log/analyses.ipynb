# %%
# Out:
# Average Loss:0.05297154188156128,Acc:98.83244037628174
# JPEG Average Loss:0.049295924603939056,Acc:99.42407608032227
# Average size:372.92724609375
# JPEG Average size:574.591796875

# %%
"""
rate= 2000 qp2=qp2*0.9
I frame qp=75
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[60:90]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[55:85]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[55:85]
"""
import numpy as np
B=1e-05        
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994579264835,Acc:97.0570534019916
# JPEG Average Loss:0.11166319681524632,Acc:97.37705905301914
# Average size:218.18445129904006
# JPEG Average size:287.776582749791

# %%
"""
rate= 10000 qp2=qp2*0.88
I frame qp=70
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[55:85]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[50:80]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[50:80]
"""
import numpy as np
B=2e-05        
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994592325119,Acc:96.57592144553769
# JPEG Average Loss:0.2353787176610036,Acc:94.51569713477706
# Average size:194.24178154997912
# JPEG Average size:223.53713550376253

# %%
"""
rate= 10000 qp2=qp2*0.85
I frame qp=65
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[50:80]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[45:75]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[45:75]
"""
import numpy as np
B=3e-05        
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.0646799457739908,Acc:95.66781723837622
# JPEG Average Loss:0.3822760019688104,Acc:91.23739917142734
# Average size:165.91334515859765
# JPEG Average size:190.67334637594064

# %%
"""
rate= 10000 qp2=qp2*0.85
I frame qp=65
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[50:80]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[45:75]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[45:75]
"""
import numpy as np
B=4e-05        
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994579886753,Acc:94.59476001274605
# JPEG Average Loss:0.4627074578833022,Acc:88.85213204450831
# Average size:146.60739742017947
# JPEG Average size:169.73453013952758

# %%
"""
rate= 105  qp2=qp2*0.78
I frame qp=55
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[40:70]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[35:65]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[35:65]
"""
import numpy as np
B=5e-05        #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994589215527,Acc:91.42964113136763
# JPEG Average Loss:0.7573432236860029,Acc:84.00070252625838
# Average size:127.54076781615191
# JPEG Average size:155.15934952445653

# %%
"""
rate= 10000  qp2=qp2*0.6
I frame qp=42
           self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[25:45]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=6e-05        #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06253225463959906,Acc:82.7400451236301
# JPEG Average Loss:0.8033804161982103,Acc:78.73782352967696
# Average size:96.76946614583333
# JPEG Average size:134.61228249289772

# %%
"""
rate= 10000  qp2=qp2*0.7
I frame qp=45
           self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[25:45]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=7e-05        #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994583618263,Acc:87.42277084885535
# JPEG Average Loss:1.0190173864962664,Acc:77.53152887159366
# Average size:109.8383846123748
# JPEG Average size:139.4529665943771

# %%
"""
rate= 10000 qp2=qp2*0.62
I frame qp=42
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[37:67]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[32:62]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=8e-05        #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994592325119,Acc:81.20477259258595
# JPEG Average Loss:1.191128616847322,Acc:76.97375705808301
# Average size:96.95153706698665
# JPEG Average size:142.95089588994566

# %%
"""
rate= 10000  qp2=qp2*0.6
I frame qp=40
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[25:55]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[17:47]
"""
import numpy as np
B=9e-05        #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994592947036,Acc:79.28720842020739
# JPEG Average Loss:1.221724792966077,Acc:74.87038864339873
# Average size:95.17768220471619
# JPEG Average size:138.0462283131271

# %%
"""
rate= 50  qp2=qp2*0.7
I frame qp=40
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[30:60]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[25:55]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.0001        #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994600410056,Acc:83.05159761432017
# JPEG Average Loss:1.4829051013674623,Acc:70.82879694807889
# Average size:118.18146944125625
# JPEG Average size:129.54210813388377

# %%
"""
rate= 10000  qp2=qp2*0.5
I frame qp=40
   self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.000102     #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994591081282,Acc:76.80676082935875
# JPEG Average Loss:1.527774120752628,Acc:70.50907978644737
# Average size:92.221480788293
# JPEG Average size:128.8432453882734

# %%
"""
rate= 10000  qp2=qp2*0.5
I frame qp=35
    self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[28:58]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.000103     #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994605385402,Acc:71.20362721221873
# JPEG Average Loss:1.7245829317681367,Acc:68.32789633186366
# Average size:86.5464967654424
# JPEG Average size:126.77306516513377

# %%
"""
rate= 10000  qp2=qp2*0.38
I frame qp=32
            elf.tables1Y = torch.load('./pth/jpeg_qtables.pth')[25:55]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.0002       #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994568692224,Acc:57.91080893578633
# JPEG Average Loss:2.251527253899686,Acc:61.538182772122894
# Average size:78.57381116965776
# JPEG Average size:116.86430190478679

# %%
"""
rate= 10000  qp2=qp2*0.4
I frame qp=22
            elf.tables1Y = torch.load('./pth/jpeg_qtables.pth')[15:45]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[10:40]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[5:35]
"""
import numpy as np
B=0.0003       #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994617823766,Acc:60.008539699751864
# JPEG Average Loss:2.908692179515609,Acc:53.2763676499842
# Average size:79.32573005790901
# JPEG Average size:101.88789454431438

# %%
"""
            rate= 5000 qp2=qp2*0.33
            I frame qp=25
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[10:40]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[5:35]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[5:35]
"""
import numpy as np
B=0.0005        #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994597922383,Acc:48.26065574544101
# JPEG Average Loss:2.705673046734022,Acc:51.65973738284414
# Average size:75.11134605853506
# JPEG Average size:91.37897320495401

# %%
"""
            rate= 45 qp2=qp2*0.8
            I frame qp=20
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[0:30]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[0:30]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[0:30]
"""
import numpy as np
B=0.001     #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994560607288,Acc:55.19172719404574
# JPEG Average Loss:4.054558061835758,Acc:43.25477486868766
# Average size:71.52273157084724
# JPEG Average size:74.65215594951923

# %%
"""
            rate= 45 qp2=qp2*0.8
            I frame qp=20
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[0:30]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[0:30]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[0:30]
"""
import numpy as np
B=0.004     #
filename="test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.064679945848621,Acc:54.92681780323162
# JPEG Average Loss:4.682157978564999,Acc:40.35233510377814
# Average size:62.59422931448247
# JPEG Average size:63.61233081626254

# %%
"""
            rate= 45 qp2=qp2*0.8
            I frame qp=20
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[0:30]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[0:30]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[0:30]
"""
import numpy as np
B=0.00004001     #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994600410056,Acc:95.42919160527657
# JPEG Average Loss:0.41931335571966444,Acc:90.52914688021045
# Average size:146.97353499321787
# JPEG Average size:186.1864287207358

# %%
import numpy as np
qp=100 #
fps=16
filename="baseline1/fps={0}-qp={1}.log".format(fps,qp)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.1647057623442306,Acc:94.3335775142918
# JPEG Average Loss:0.0,Acc:0.0
# Average size:1113.1116498353888
# JPEG Average size:1480.8583984375

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

V=[
    #59.18,#0.01
    62.59,#0.004
#71.52,#0.001
#75.11,#0.0005
#79.32,#0.0003
#78.57,#B=0.0002
86.54,# #B=0.0001003
92.22,#B=0.0001
95.17,#B=9e-05
96.95,#B=8e-05
109.83,#B=7e-05
119.78,#B=6.002e-05
146.60,#4e-05
165.91,
194.24,
218.18,
372.92]
Accuracy=[
    #64.32,
    54.92,#0.004
#55.19,#B=0.001
#48.26,#B=0.0005
#60.00,#B=0.0003
#57.91,#B=0.0002
71.20, #B=0.0001003
76.80,#B=0.0001
79.28,#B=9e-05
81.20,#B=8e-05
87.42,#B=7e-05 
90.18,#B=6.002e-05
94.59,#4e-05
95.66,
96.57,
97.05,
98.83]
jpeg_V=[
    63.61,
    #63.61,
#74.65,#0.001
#91.37,#0.0005
#101.88,#0.0003
#116.86,#B=0.0002
#126.77,#B=0.0001003
#128.84,#B=0.0001
131.68,
#142.95,
#139.45,
#146.06,#B=6.002e-05
160.73,
190.67,
223.53,
287.77,
574.59]
jpeg_Accuracy=[
    40.35,
    #40.35,
#43.25,#0.001
#51.65,#0.0005
#53.27,#0.0003
#61.53,#B=0.0002
#68.32,#B=0.0001003
#70.50,#B=0.0001
74.87,#B=9e-05
#76.97,#B=8e-05
#77.53,#B=7e-05
#79.91,#B=6.002e-05
88.85,
91.23,
94.51,
97.37,
99.42]
jpeg_real_V=[
    # 0,
    #0,
    0,
    0,
    0,
    # 59.08,
    72.58,
    88.69,
    104.43,
    118.85,#39
    134.05,#49
    151.18,
    179.19,
    228.23,
    360.40,
    1490.18
]
jpeg_real_acc=[
    #0,
    0,
    0,
    #0,
    0,
    # 40.21,
    34.32,
    43.35,
    56.34,
    69.47,
    79.92,
    86.92,
    93.59,
    97.18,
    98.61,
    99.63
]

V_fps=[
    43.17,
    62.45,#0.000103
    68.21,#8.001e-05
    70.85,#8e-05
    71.54,#7.5e-05
    #73.99,#6e-05
    74.13,#7e-05
    82.91,#5.001e-05
    #84.60,#5e-05
    #98.21,#4.001
    100.11,#4e-05
    145.69,#1e-05
178.66,#5.001e-06
230.32,#5e-06
230.32,
#230.32
]
Acc_fps=[
    51.77,
    71.06,
    77.71,
    80.00,
    86.08,#7.5e-05
    #82.52,#6e-05
    89.15,#7e-05
    93.40,#5.001e-05
    #96.74,#5e-05
    #93.39,
    95.06,#4e-05
    95.76,
    96.86,
    97.89,
    97.89,
    #97.89,
    # 97.89,
    # 97.89
]

colors=np.random.rand(12)
plt.scatter(V,Accuracy,c="orange",marker="*")
plt.scatter(jpeg_V,jpeg_Accuracy,c="blue",marker="+",alpha=0.5)
plt.scatter(jpeg_real_V,jpeg_real_acc,c="green",marker="x",alpha=0.5)
#plt.scatter(V_fps,Acc_fps,c=colors,marker="x")#fps=10

plt.plot(V,Accuracy,c="red")#table index2
plt.plot(jpeg_V,jpeg_Accuracy)#table index1
plt.plot(jpeg_real_V,jpeg_real_acc,c=[0,0.8,0])#jpeg
#plt.plot(V_fps,Acc_fps)
plt.legend(["Inter","Intra","jpeg"],loc=4,fontsize=10)
plt.annotate("{0},{1}".format(round(V[0],0),round(Accuracy[0],0)),xy=(V[0],Accuracy[0]),fontsize=10)
plt.annotate("{0},{1}".format(round(jpeg_V[0],0),round(jpeg_acc[0],0)),xy=(jpeg_V[0],jpeg_acc[0]),fontsize=10)

plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
# plt.xlim(0,400)
# plt.ylim(50,100)
plt.savefig("results2.png")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"""fps difference"""
V=[
    #58,
    62.59,#0.004
#71.52,#0.001
#75.11,#0.0005
#79.32,#0.0003
#78.57,#B=0.0002
86.54,# #B=0.0001003
92.22,#B=0.0001
95.17,#B=9e-05
96.95,#B=8e-05
109.83,#B=7e-05
119.78,#B=6.002e-05
146.60,#4e-05
165.91,
194.24,
218.18, 
372.92]
Accuracy=[
    #59,
    54.92,#0.004
#55.19,#B=0.001
#48.26,#B=0.0005
#60.00,#B=0.0003
#57.91,#B=0.0002
71.20, #B=0.0001003
76.80,#B=0.0001
79.28,#B=9e-05
81.20,#B=8e-05
87.42,#B=7e-05 
90.18,#B=6.002e-05
94.59,#4e-05
95.66,
96.57,
97.05,
98.83]
jpeg_real_V=[
    # 0,
   # 0,
    0,
    0,
    0,
    # 59.08,
    72.58,
    88.69,
    104.43,
    118.85,#39
    134.05,#49
    151.18,
    179.19,
    228.23,
    360.40,
    #1490.18
]
jpeg_real_acc=[
    # 0,
    0,
    0,
    #0,
    0,
    # 40.21,
    34.32,
    43.35,
    56.34,
    69.47,
    79.92,
    86.92,
    93.59,
    97.18,
    98.61,
    #99.63
]

V_fps10=[
    43.17,#0.001001
    #62.45,#0.000103
    63.16,#0.000104  
    #68.21,#8.001e-05
    69.40,#8.002e-05
    #70.85,#8e-05
    #71.54,#7.5e-05
    #73.99,#6e-05
    #74.13,#7e-05
    82.91,#5.001e-05
    #84.60,#5e-05
    #98.21,#4.001
    100.11,#4e-05
    145.69,#1e-05
178.66,#5.001e-06

230.32,#5e-06

298
]
Acc_fps10=[
    51.77,
    #71.06,
    80.55,
    #77.71,
    88.03,
    #80.00,
    #86.08,#7.5e-05
    #82.52,#6e-05
    #89.15,#7e-05
    93.40,#5.001e-05
    #96.74,#5e-05
    #93.39,
    95.06,#4e-05
    95.76,
    96.86,
    97.89,
    98.4
]
V_H264_QP20=[1.78,1.97,3.07,4.92,8.30,15.14,32.08,71.49,157.65,376.11
,721.22,1020.70
]
Acc_H264_QP20=[28.89,30.52,32.95,41.41,56.93,73.79,85.89,94.70,97.61,98.47
,98.82,98.96
]
V_GOP34_H264=[1.88,2.10,3.28,5.26,8.86,16.43,33.96,74.37,162.45,
382.55,728.06,1023.29
]
Acc_GOP34_H264=[30.29,30.66,32.90,39.46,53.81,71.95,84.86,94.42,97.64,
98.49,98.82,98.96
 ]

V_fps6=[
21.08,#0.01
#23.34,#0.006
23.91,#0.002
23.77,#0.005001
22.07,#0.005
#27.75,#0.001
37.06,#0.0003
42.04,#0.0001001
50.15,#8e-05

     #50.83,#6e-05
     #51.66,#5e-05
     64.48,#4e-05
     96.59,#1e-05
     141.18,#5e-06
     328.36#1e-06
     ]

Acc_fps6=[
50.49,
    #52.25,
    69.86,
    77.24,
    84.22,
    #80.50,
    89.42,
    91.35,
    93.68,
    #92.41,
    #94.46,
    94.34,
    95.12,
    96.54,
    97.42]
V_fps3=[
    18.15,#0.0003
    20.16,#0.0001
    24.79,#8.001e-05
    25.98,#6e-05
    26.98,#5e-05
    29.06,#5.001e-05
    32.37,#4e-05
    35.95,#4.002e-05
    
    49.27,#0.00001
]
Acc_fps3=[
    53.63,
    63.29,
   77.83,
   81.83,
   83.50,
   86.89,
   89.29,
   91.22,
   93.79]
our_V_h264=[60.56,66.52,72.99,86.57,95.24,110,137.65,219.38,369.85,1113.72]
our_Acc_h264=[10.82,21.25,43.14,71.25,79.26,87.61,93.81,97.12,98.35,99.16]
our_V_h264_2s=[70.39,83.73,92.31,107.02,134.72,218.09,369.37,1114.44]
our_Acc_h264_2s=[42.56,71.52,79.59,87.92,94.15,97.52,98.59,99.22]
V_new=[
    86.2,
   93.58,
    97.15,
    #111.29,
    100.91,
    108.29,
    #111.76,
    #111.0,
    #132.65,
 
    112.42,
    118.55,
    118.92,
    120.72,
    124.03,
    #128.00,
    #111.33,
    127.36,
    146.97,
    221.16,
    ]
Acc_new=[
    73.87,#2.002e-04
    81.69, #2.001e-04
    83.69,#0.7  6e-05
    #90.61,#0.8 6e-05
    86.11,#8e-05
    89.9,# 6.007E-05
    #90.87,#0.8 6.006e-05 
    #90.49, # 0.8 7e-05
    #92.78,
    
    92.82, #0.83  6.005e-05
    92.53,
    92.59, #0.832 6.0010e-05
    93.07,#0.84 6.0009e-05
    93.44,# 0.85 6.0008e-05
    #93.14,  #0.87 7e-05
    #90.54,#5e-05
    93.91,  # 0.85 5.004e=05
    95.41,#4,001e-05
    97.28,#1.001e-05
    ]


colors=np.random.rand(12)
#plt.scatter(jpeg_real_V,jpeg_real_acc,c="black",marker="o",alpha=0.5)
#plt.scatter(V_GOP34_H264,Acc_GOP34_H264,c="orange",marker="o")
# plt.scatter(V,Accuracy,c="red",marker="*",alpha=0.5)#fps=17
#plt.scatter(V_fps10,Acc_fps10,c="blue",marker="x",alpha=0.5)
plt.scatter(our_V_h264,our_Acc_h264,c="blue",marker="*",alpha=0.5)
# plt.scatter(our_V_h264_2s,our_Acc_h264_2s,c="green",marker="*",alpha=0.5)

plt.scatter(V_new,Acc_new,c="red",alpha=0.5)

#plt.scatter(V_fps3,Acc_fps3,c="green",marker="o",alpha=0.5)

# plt.plot(V,Accuracy,c=[0.8,0,0],alpha=0.5)#fps=17
#plt.plot(jpeg_real_V,jpeg_real_acc,c="black",alpha=0.4)#jpeg
#plt.plot(V_fps10,Acc_fps10,c="blue",alpha=0.4)#fps=10
#plt.plot(V_H264_QP20,Acc_H264_QP20,c="green")#H264
#plt.plot(V_GOP34_H264,Acc_GOP34_H264,c="orange")#H264
#plt.plot(V_fps3,Acc_fps3,c="green",alpha=0.4)
plt.plot(our_V_h264,our_Acc_h264,c="blue",alpha=0.5)
# plt.plot(our_V_h264_2s,our_Acc_h264_2s,c="green",alpha=0.5)
plt.plot(V_new,Acc_new,c="red",alpha=0.4)
#plt.plot(V_fps3,Acc_fps3,c="green",alpha=0.4)
plt.legend(["H264","fps=17"],loc=4,fontsize=10)
#plt.annotate("{0},{1}".format(round(V[3],3),round(Accuracy[3],3)),xy=(V[3],Accuracy[3]),fontsize=10)
#plt.annotate("{0},{1}".format(round(jpeg_V[3],3),round(jpeg_acc[3],3)),xy=(jpeg_V[3],jpeg_acc[3]),fontsize=10)
plt.xlabel("V/KB")
plt.ylabel("Accuracy/(%)")
plt.ylim(70,100)
plt.xlim(80,160)
plt.savefig("results3.png")
plt.show()

# %%
"""
qp2=qp2*0.85
I frame qp=65
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[50:80]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[45:75]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[45:75]
"""
import numpy as np
B=4.001e-05        
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994600410056,Acc:95.42919160527657
# JPEG Average Loss:0.41931335571966444,Acc:90.52914688021045
# Average size:146.97353499321787
# JPEG Average size:186.1864287207358

# %%
"""
 qp2=qp2*0.93
I frame qp=75
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[60:90]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[55:85]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[55:85]
"""
import numpy as np
B=1.001e-05        
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994592947036,Acc:97.28435339633133
# JPEG Average Loss:0.11171484726752126,Acc:97.37616183367062
# Average size:221.16501460767947
# JPEG Average size:287.75139788879596

# %%
"""
qp2=qp2*0.73
I frame qp=42
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[37:67]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[32:62]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=8.001e-05        #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994602897728,Acc:86.11199827942507
# JPEG Average Loss:1.1911534585282955,Acc:76.97282188313461
# Average size:100.91373969636895
# JPEG Average size:142.95067869460703

# %%
"""
qp2=qp2*0.6
I frame qp=40
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.000104        #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.05058111995458603,Acc:73.24333190917969
# JPEG Average Loss:nan,Acc:nan
# Average size:115.427734375
# JPEG Average size:nan
# /home/xxd/anaconda3/envs/drn/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/xxd/anaconda3/envs/drn/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
"""
qp2=qp2*0.8
I frame qp=40
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.00006003        #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if line>3*34:break
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06418984731038412,Acc:91.13448778788249
# JPEG Average Loss:0.7856125640017646,Acc:78.19251332964215
# Average size:105.71634114583334
# JPEG Average size:133.517578125

# %%
"""
qp2=qp2*0.87
I frame qp=45
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[25:45]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.00007002        #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if line >3*34:break
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06418984805544217,Acc:93.9771302541097
# JPEG Average Loss:0.807821763413293,Acc:77.6383536202567
# Average size:121.0119140625
# JPEG Average size:132.43638392857142

# %%
"""
qp2=qp2*0.8
I frame qp=45
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[25:45]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.00007003        #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.064679945848621,Acc:90.49642448234239
# JPEG Average Loss:1.0190889106247338,Acc:77.53034411465444
# Average size:111.0085314717237
# JPEG Average size:139.44918608904683

# %%
"""
qp2=qp2*0.85
I frame qp=60
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[40:70]
self.tables1U = torch.load('./pth/jpeg_qtables.pth')[35:65]
self.tables1V = torch.load('./pth/jpeg_qtables.pth')[35:65]
"""
import numpy as np
B=0.00005004    #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994586727854,Acc:93.9136113467718
# JPEG Average Loss:0.7573976241874456,Acc:84.00040526055173
# Average size:127.3659223706177
# JPEG Average size:155.15030407347408

# %%
"""
qp2=qp2*0.83
I frame qp=50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=0.00006005      #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if line>3*34:break
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.0641898475587368,Acc:92.8247865041097
# JPEG Average Loss:1.0857295393943787,Acc:74.10188061850411
# Average size:112.42180989583333
# JPEG Average size:134.97440011160714

# %%
"""
qp2=qp2*0.8
I frame qp=50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=0.00006006      #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if line>3*34:break
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06418984830379486,Acc:90.64737319946289
# JPEG Average Loss:1.0848812801497323,Acc:74.11620276314872
# Average size:106.65983072916667
# JPEG Average size:134.97370256696428

# %%
"""
qp2=qp2*0.8
I frame qp=50
           self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[25:55]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.00006007     #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
#   if line>3*34:break
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994587349772,Acc:89.9066132973749
# JPEG Average Loss:1.74739879678723,Acc:68.32128727316457
# Average size:108.29489252921536
# JPEG Average size:126.73939988764631

# %%
"""
qp2=qp2*0.85
I frame qp=50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=0.00006008     #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
#   if line>3*34:break
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994597300464,Acc:93.44071378691964
# JPEG Average Loss:1.2408565966082257,Acc:76.2843714111226
# Average size:124.03546764138147
# JPEG Average size:142.89017101275084

# %%
"""
qp2=qp2*0.84
I frame qp=50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=0.00006009     #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
#   if line>3*34:break
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.0646799460973883,Acc:93.07158275916302
# JPEG Average Loss:1.240643016420878,Acc:76.28752515467512
# Average size:120.72481642581386
# JPEG Average size:142.89018897627508

# %%
"""
qp2=qp2*0.832
I frame qp=50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=0.00006010    #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
#   if line>3*34:break
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994597922383,Acc:92.59331230329154
# JPEG Average Loss:1.2407875698446031,Acc:76.28809353180952
# Average size:118.92447862322621
# JPEG Average size:142.88913729358276

# %%
"""
qp2=qp2*0.832
I frame qp=50
            self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[35:65]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[30:60]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[25:55]
"""
import numpy as np
B=0.00007004    #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
#   if line>3*34:break
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994589837445,Acc:92.53823546216961
# JPEG Average Loss:1.2869558876075076,Acc:75.60705771813026
# Average size:118.55334085454925
# JPEG Average size:141.49293870192307

# %%
"""
rate= 50  qp2=qp2*0.7
I frame qp=32
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[25:55]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.0002001       #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994587349772,Acc:81.69827309992158
# JPEG Average Loss:2.2511322395658016,Acc:61.541499023054755
# Average size:93.58892913971202
# JPEG Average size:116.86098191889631

# %%
"""
rate= 50  qp2=qp2*0.6
I frame qp=32
self.tables1Y = torch.load('./pth/jpeg_qtables.pth')[25:55]
            self.tables1U = torch.load('./pth/jpeg_qtables.pth')[20:50]
            self.tables1V = torch.load('./pth/jpeg_qtables.pth')[15:45]
"""
import numpy as np
B=0.0002002       #
filename="fps=17/test-B={0}.log".format(B)
file = open(filename, 'r')
line=0
loss_data=[]
V_data=[]
for eachline in file:
  if eachline.find("Loss") >= 0 and line>0:
      loss_data.append(eachline)
  if eachline.find("jpeg_size") >= 0 and line>0:
      V_data.append(eachline)
  line+=1
file.close()
loss=[]
acc=[]
jpeg_loss=[]
jpeg_acc=[]
V=[]
V_jpeg=[]
index=0
for info in loss_data:
    info=info.split(" ")[4].split(",")
    loss.append(float(info[0].split(":")[1]))
    acc.append(float(info[1].split(":")[1]))
    if index>0:
        jpeg_loss.append(float(info[2].split(":")[1]))
        jpeg_acc.append(float(info[3].split(":")[1].strip('\n')))
    index+=1
average_loss=np.mean(np.abs(np.array(loss)))
average_acc=np.mean(np.abs(np.array(acc)))
average_jpeg_loss=np.mean(np.abs(np.array(jpeg_loss)))
average_jpeg_acc=np.mean(np.abs(np.array(jpeg_acc)))
print("Average Loss:{0},Acc:{1}".format(average_loss,average_acc))
print("JPEG Average Loss:{0},Acc:{1}".format(average_jpeg_loss,average_jpeg_acc))
index=0
for info in V_data:
    info=info.split(",")
    V.append(float(info[-2].split(":")[1]))
    if index>0:
        V_jpeg.append(float(info[-1].split(":")[1]))
    index+=1
average_V=np.mean(np.abs(np.array(V)))
average_V_jpeg=np.mean(np.abs(np.array(V_jpeg)))
print("Average size:{0}".format(average_V))
print("JPEG Average size:{0}".format(average_V_jpeg))
# Out:
# Average Loss:0.06467994596056628,Acc:73.87372018498849
# JPEG Average Loss:2.250747190670026,Acc:61.54164502453246
# Average size:86.20395157293406
# JPEG Average size:116.85654492840719
